# %% [markdown]
# ## dla INFORMACJA ZARZĄDCZA
#
# ilość klientów którzy przychodzą do sklepu w ciągu godziny
#
#  - W ciągu 2 kluczowych godzin sprzedaży przyszły 254 osoby - to znaczy, że średnia częstotliwość przyjść wynosił 253/2= 127 osób na godzinę.
#
# ŚREDNIA CZAS obsłużenia osób
#   - W ciągu 2 kluczowych godzi, każdy POS obsłużuguje średnio 33 osóby w ciągu godziny - to znaczy, że średni czas rozładunków wynosił 53/11= 4.82 samochodu na godzinę.
#  - Czyli 11/53 = 0.2075 godziny na samochód, (11*60)/53 = 12.4528 minut

# %%
60/29
# Out:
# 2.0689655172413794

# %% [markdown]
# <span style="font-size: 180%;color:black">
# $$\text{Wskaźnik intensywności ruchu:} \\
# {
# {ϱ}=\frac{λ}{{μ}\times{r}}
# } \qquad (1)
# $$

# %%
def factorial(n): 
    return 1 if (n==1 or n==0) else n * factorial(n - 1);

# %% [markdown]
# # 1. Prawdopodobieństwo, że nie będzie kolejki

# %% [markdown]
# <span style="font-size: 180%;color:black">
# $${
# {\displaystyle\sum_{i=0}^{r-1} \frac{𝜚^i}{i!}}
# }\qquad $$

# %% [markdown]
# <span style="font-size: 180%;color:black">
# $${
# {\displaystyle\sum_{i=0}^{r-1} \frac{𝜚^i}{i!}}= \frac{0.9^{(1-1)}}{{(1-1)}!}+\frac{0.9^{(2-1)}}{{(2-1)}!}+\frac{0.9^{(3-1)}}{{(3-1)}!}=1+0.9+0.405 \approx 2.305
# }\qquad $$

# %%
def dzings(ϱ,r):
    
    a1 = (ϱ**0)/factorial(0) # gdy kanałów jest r=1 wtedy NT = 1
    a2 = a1+(ϱ**1)/factorial(1) # gdy kanałów jest r=2 wtedy NT = a0
    a3 = a2+(ϱ**2)/factorial(2) # gdy kanałów jest r=3 wtedy NT = a0 + a1 
    a4 = a3+(ϱ**3)/factorial(3) # gdy kanałów jest r=4 wtedy NT = a0 + a1 + a2 
    a5 = a4+(ϱ**4)/factorial(4) # gdy kanałów jest r=5 wtedy NT = a0 + a1 + a2 + a3 
    a6 = a5+(ϱ**5)/factorial(5) # gdy kanałów jest r=6 wtedy NT = a0 + a1 + a2 + a3 + a4
    a7 = a6+(ϱ**6)/factorial(6) # gdy kanałów jest r=7 wtedy NT = a0 + a1 + a2 + a3 + a4 + a5
    a8 = a7+(ϱ**7)/factorial(7) # gdy kanałów jest r=8 wtedy NT = a0 + a1 + a2 + a3 + a4 + a5 + a6
    a9 = a8+(ϱ**8)/factorial(8) # gdy kanałów jest r=9 wtedy NT = a0 + a1 + a2 + a3 + a4 + a5 + a6 + a7
    a10 = a9+(ϱ**9)/factorial(9) # gdy kanałów jest r=9 wtedy NT = a0+a1+a2+a3+a4+a5+a6+a7+a8


    if r == 1:
        NT = a1
    else:
        if r == 2:
            NT = a2
        else:
            if r == 3:
                NT = a3
            else:   
                if r == 4:
                    NT = a4
                else:   
                    if r == 5:
                        NT = a5
                    else:                       
                        if r == 6:
                            NT = a6
                        else:
                            if r == 7:
                                NT = a7
                            else:
                                if r == 8:
                                    NT = a8
                                else:
                                    if r == 9:
                                        NT = a9
                                    else:
                                        if r == 10:
                                            NT = a10
    return NT

# %% [markdown]
# <span style="font-size: 180%;color:black"> Prawdopodobieństwo, że nie będzie kolejki przed dokami

# %% [markdown]
# <span style="font-size: 180%;color:black">
# $$
# {p(n=0) =\frac{1}{\displaystyle\sum_{i=0}^{r-1} \frac{𝜚^i}{i!}+\frac{𝜚^r}{{\left(r-{𝜚}\right)}{\left(r-1\right)!}}}}
# \qquad (2)$$

# %%
def prawd_braku_kolejki(ϱ,r):
    
    pbk=1/(NT+(((ϱ**r)/((r-ϱ)*factorial(r-1)))))
    
    return pbk

# %% [markdown]
# ### Prawdopodobieństwo, że będzie kolejka przed dokami
#
#         n - ilość samochodów

# %% [markdown]
# <span style="font-size: 180%;color:black">
# $$\\
#  {p(n) =\begin{cases}
# \frac{{ϱ^n}{p(n=0)}}{n!},  & \text{if $n\le r$} \\[2ex]
# \frac{{r^{r-n}}{ϱ^n}{p(n=0)}}{r!},  & \text{if $n\gt r$} \\[2ex]
# \end{cases}
# } \qquad (3)
# $$

# %%
def prawd_kolejki(ϱ,r,n,PBK):
    
        if n <= r:
            pt=(((ϱ**n)*PBK)/factorial(n))
        else: 
            pt=(((r**(r-n))*(ϱ**(n))*PBK))/(factorial(r))
        
        return pt

# %%
prawd_kolejki(0.95,2,3,0.36)
# Out:
# 0.07716374999999999

# %% [markdown]
# ## ŚREDNIA ILIŚĆ CIĘŻARÓWEK czekających na podjeździe

# %% [markdown]
# <span style="font-size: 180%;color:black">
#
# $$\
# {
# ψ =\frac{{𝜚^{r+1}{p(n=0)}}}{{(r-𝜚)}^2{(r-1)!}}
# } \qquad (4)
# $$

# %%
def ile_sztuk_czeka(ϱ,r,PBK):

    ISC = ((𝜚**(r+1))*PBK)/(((r-𝜚)**2)*factorial(r-1))
    
    return ISC

# %% [markdown]
# ## Prawdopodobieństwo, że spędzimy t czasu w kolejce

# %% [markdown]
# <span style="font-size: 180%;color:black">
# $$
# {
# p(t>t_0) ={{p{(n>r-1)}}{e^{-μt_0(r-𝜚)}}}
# } \qquad (5)
# $$

# %%
def prawdop_czasu(μ,r,𝜚,PBK, P1, t):
      
    import numpy as np
       
    PC = (1-(PBK+P1))*(np.e**(-μ*t*(r-𝜚)))
    
    return PC

# %%
60*0.15
# Out:
# 9.0

# %%
552*2
# Out:
# 1104

# %% [markdown]
# # ZADANIE

# %% [markdown]
# # Dział produkcyjny ZPAP Myszków

# %%
λ=32.40    # ile jest przyjeżdzających wózków z gorącmymi detalami na godzinę
μ=3.12     # ile ile jest obsługiwanych gorących detali na godzinę  
r=6      # ile jest maszyn zakładających element na wcisk
t=0.15   # czas 9 minut, czas w którym detal schładza sie do temperatury, która obniża jakość łaczenia, awaria łączników

ϱ = λ/(μ*r)

NT = dzings(ϱ,r)

PBK = prawd_braku_kolejki(ϱ,r)
ISC = ile_sztuk_czeka(ϱ,r,PBK)


P1 = prawd_kolejki(ϱ,r,1,PBK)
P2 = prawd_kolejki(ϱ,r,2,PBK)
P3 = prawd_kolejki(ϱ,r,3,PBK)
P4 = prawd_kolejki(ϱ,r,4,PBK)
P5 = prawd_kolejki(ϱ,r,5,PBK)
P6 = prawd_kolejki(ϱ,r,6,PBK)
P7 = prawd_kolejki(ϱ,r,7,PBK)
P8 = prawd_kolejki(ϱ,r,8,PBK)

SP = PBK+P1+P2+P3+P4+P5+P6+P7+P8
PC = prawdop_czasu(μ,r,𝜚,PBK, P1, t)

ϱ_Mysz = ϱ
λ_Mysz = λ
μ_Mysz = μ
r_Mysz = r

# %% [markdown]
# # Dział produkcyjny ZPAP Kotowiec

# %%
λ=21.40    # ile jest przyjeżdzających wózków z gorącmymi detalami na godzinę
μ=5.52     # ile ile jest obsługiwanych gorących detali na godzinę  
r=4      # ile jest maszyn zakładających element na wcisk
t=0.15   # czas 9 minut, czas w którym detal schładza sie do temperatury, która obniża jakość łaczenia, awaria łączników

ϱ = λ/(μ*r)
ϱ

NT = dzings(ϱ,r)

PBK_a = prawd_braku_kolejki(ϱ,r)
ISC_a = ile_sztuk_czeka(ϱ,r,PBK_a)


P1_a = prawd_kolejki(ϱ,r,1,PBK_a)
P2_a = prawd_kolejki(ϱ,r,2,PBK_a)
P3_a = prawd_kolejki(ϱ,r,3,PBK_a)
P4_a = prawd_kolejki(ϱ,r,4,PBK_a)
P5_a = prawd_kolejki(ϱ,r,5,PBK_a)
P6_a = prawd_kolejki(ϱ,r,6,PBK_a)
P7_a = prawd_kolejki(ϱ,r,7,PBK_a)
P8_a = prawd_kolejki(ϱ,r,8,PBK_a)

SP_a =PBK_a+P1_a+P2_a+P3_a+P4_a+P5_a+P6_a+P7_a+P8_a

PC_a = prawdop_czasu(μ,r,𝜚, PBK_a, P1_a, t)

ϱ_KOTo = ϱ
λ_KOTo = λ
μ_KOTo = μ
r_KOTo = r

# %% [markdown]
# #  Dział produkcyjny ZPAP Łapy

# %%
λ=49.21    # ile jest przyjeżdzających wózków z gorącmymi detalami na godzinę
μ=5.52     # ile ile jest obsługiwanych gorących detali na godzinę  
r=9      # ile jest maszyn zakładających element na wcisk
t=0.15   # czas 9 minut, czas w którym detal schładza sie do temperatury, która obniża jakość łaczenia, awaria łączników


ϱ = λ/(μ*r)
ϱ

NT = dzings(ϱ,r)

PBK_b = prawd_braku_kolejki(ϱ,r)
ISC_b = ile_sztuk_czeka(ϱ,r,PBK_b)


P1_b = prawd_kolejki(ϱ,r,1,PBK_b)
P2_b = prawd_kolejki(ϱ,r,2,PBK_b)
P3_b = prawd_kolejki(ϱ,r,3,PBK_b)
P4_b = prawd_kolejki(ϱ,r,4,PBK_b)
P5_b = prawd_kolejki(ϱ,r,5,PBK_b)
P6_b = prawd_kolejki(ϱ,r,6,PBK_b)
P7_b = prawd_kolejki(ϱ,r,7,PBK_b)
P8_b = prawd_kolejki(ϱ,r,8,PBK_b)

SP_b =PBK_b+P1_b+P2_b+P3_b+P4_b+P5_b+P6_b+P7_b+P8_b

PC_b = prawdop_czasu(μ,r,𝜚, PBK_b, P1_b, t)

ϱ_Lapy = ϱ
λ_Lapy = λ
μ_Lapy = μ
r_Lapy = r

# %% [markdown]
# #  Dział produkcyjny ZPAP Wola

# %%
#λ=3.8    # ile jest przyjeżdzających wózków z gorącmymi detalami na godzinę
#μ=2.0     # ile ile jest obsługiwanych gorących detali na godzinę  
#r=2      # ile jest maszyn zakładających element na wcisk
#t=0.5   # czas 2 minut, czas w którym detal schładza sie do temperatury, która obniża jakość łaczenia, awaria łączników


λ=9.70    # ile jest przyjeżdzających wózków z gorącmymi detalami na godzinę
μ=5.52     # ile ile jest obsługiwanych gorących detali na godzinę  
r=3      # ile jest maszyn zakładających element na wcisk
t=0.1   # czas 6 minut, czas w którym detal schładza sie do temperatury, która obniża jakość łaczenia, awaria łączników




ϱ = λ/(μ*r)
ϱ

NT = dzings(ϱ,r)

PBK_c = prawd_braku_kolejki(ϱ,r)
ISC_c = ile_sztuk_czeka(ϱ,r,PBK_c)


P1_c = prawd_kolejki(ϱ,r,1,PBK_c)
P2_c = prawd_kolejki(ϱ,r,2,PBK_c)
P3_c = prawd_kolejki(ϱ,r,3,PBK_c)
P4_c = prawd_kolejki(ϱ,r,4,PBK_c)
P5_c = prawd_kolejki(ϱ,r,5,PBK_c)
P6_c = prawd_kolejki(ϱ,r,6,PBK_c)
P7_c = prawd_kolejki(ϱ,r,7,PBK_c)
P8_c = prawd_kolejki(ϱ,r,8,PBK_c)

SP_c =PBK_c+P1_c+P2_c+P3_c+P4_c+P5_c+P6_c+P7_c+P8_c

PC_c = prawdop_czasu(μ,r,𝜚, PBK_c, P1_c, t)

ϱ_wol = ϱ
λ_wol = λ
μ_wol = μ
r_wol = r

# %% [markdown]
# #  Dział produkcyjny ZPAP Rogi

# %%
λ=12.70    # ile jest przyjeżdzających wózków z gorącmymi detalami na godzinę
μ=5.52     # ile ile jest obsługiwanych gorących detali na godzinę  
r=5      # ile jest maszyn zakładających element na wcisk
t=0.1   # czas 2 minut, czas w którym detal schładza sie do temperatury, która obniża jakość łaczenia, awaria łączników


ϱ = λ/(μ*r)
ϱ

NT = dzings(ϱ,r)

PBK_d = prawd_braku_kolejki(ϱ,r)
ISC_d = ile_sztuk_czeka(ϱ,r,PBK_d)


P1_d = prawd_kolejki(ϱ,r,1,PBK_d)
P2_d = prawd_kolejki(ϱ,r,2,PBK_d)
P3_d = prawd_kolejki(ϱ,r,3,PBK_d)
P4_d = prawd_kolejki(ϱ,r,4,PBK_d)
P5_d = prawd_kolejki(ϱ,r,5,PBK_d)
P6_d = prawd_kolejki(ϱ,r,6,PBK_d)
P7_d = prawd_kolejki(ϱ,r,7,PBK_d)
P8_d = prawd_kolejki(ϱ,r,8,PBK_d)

SP_d =PBK_d+P1_d+P2_d+P3_d+P4_d+P5_d+P6_d+P7_d+P8_d

PC_d = prawdop_czasu(μ,r,𝜚, PBK_d, P1_d, t)

ϱ_Rogi = ϱ
λ_Rogi = λ
μ_Rogi = μ
r_Rogi = r

# %%
from prettytable import PrettyTable
t = PrettyTable(["", "ZPAP Myszków","ZPAP Kotowiec","ZPAP Łapy","ZPAP Wola","ZPAP Rogi"])

t.align["Sulejówek PKP"] = "i"
t.padding_width = 1
t.add_row(['Liczba pras do łączenia detali (r)', r_Mysz,  r_KOTo,  r_Lapy,  r_wol,r_Rogi])
t.add_row(['Liczba elem. przychodzących na h (λ) ', λ_Mysz, λ_KOTo,  λ_Lapy, λ_wol,λ_Rogi])
t.add_row(['Liczba operacji na poj. prasie na h (μ)',  μ_Mysz, μ_KOTo,  μ_Lapy, μ_wol,μ_Rogi])
t.add_row(['Wskaźnik intensywności ruchu ϱ=λ/(μ*r)',  round(ϱ_Mysz,2), round(ϱ_KOTo,2), round(ϱ_Lapy,2), round(ϱ_wol,2), round(ϱ_Rogi,2)])
print(t)
# Out:
# +-----------------------------------------+--------------+---------------+-----------+-----------+-----------+
# |                                         | ZPAP Myszków | ZPAP Kotowiec | ZPAP Łapy | ZPAP Wola | ZPAP Rogi |
# +-----------------------------------------+--------------+---------------+-----------+-----------+-----------+
# |    Liczba pras do łączenia detali (r)   |      6       |       4       |     9     |     2     |     5     |
# |  Liczba elem. przychodzących na h (λ)   |     32.4     |      21.4     |   49.21   |    3.8    |    12.7   |
# | Liczba operacji na poj. prasie na h (μ) |     3.12     |      5.52     |    5.52   |    2.0    |    5.52   |
# |  Wskaźnik intensywności ruchu ϱ=λ/(μ*r) |     1.73     |      0.97     |    0.99   |    0.95   |    0.46   |
# +-----------------------------------------+--------------+---------------+-----------+-----------+-----------+

# %%
from prettytable import PrettyTable
t = PrettyTable(["","ZPAP Myszków","ZPAP Kotowiec","ZPAP Łapy","ZPAP Wola","ZPAP Rogi"])

t.align[""] = "l"
t.padding_width = 1
t.add_row(['Liczba pras do łączenia detali (r)', r_Mysz,  r_KOTo,  r_Lapy,  r_wol,r_Rogi])
t.add_row(['Liczba elem. przychodzących na h (λ) ', λ_Mysz, λ_KOTo,  λ_Lapy, λ_wol,λ_Rogi])
t.add_row(['Liczba operacji na poj. prasie na h (μ)',  μ_Mysz, μ_KOTo,  μ_Lapy, μ_wol,μ_Rogi])
t.add_row(['Wskaźnik intensywności ruchu ϱ=λ/(μ*r)',  round(ϱ_Mysz,2), round(ϱ_KOTo,2), round(ϱ_Lapy,2), round(ϱ_wol,2), round(ϱ_Rogi,2)])
t.add_row(['----------',  '----------', '----------', '----------', '----------', '----------'])
t.add_row(['Prawdopodobieństwo braku kolejki',  round(PBK,2), round(PBK_a,2), round(PBK_b,2), round(PBK_c,2),round(PBK_d,2)])
t.add_row(['Prawdopodobieństwo oczekiwania 1 detalu',  round(P1,2), round(P1_a,2), round(P1_b,2), round(P1_c,2),round(P1_d,2)])
t.add_row(['Prawdopodobieństwo oczekiwania 2 detali',  round(P2,2), round(P2_a,2), round(P2_b,2), round(P2_c,2), round(P2_d,2)])
t.add_row(['Prawdopodobieństwo oczekiwania 3 detali',  round(P3,2), round(P3_a,2), round(P3_b,2), round(P3_c,2), round(P3_d,2)])
t.add_row(['Suma prawdopodobieństw:',                round(SP,2), round(SP_a,2), round(SP_b,2), round(SP_c,2), round(SP_d,2)])
t.add_row(['----------',  '----------', '----------', '----------','----------','----------'])
t.add_row(['Prawd. oczekiwania powyżej 6 minut',  round(PC,3), round(PC_a,3), round(PC_b,3), round(PC_c,3), round(PC_d,3)])
t.add_row(['Przeciętna ilość detali w kolejce',  round(ISC,2), round(ISC_a,2), round(ISC_b,2), round(ISC_c,2), round(ISC_d,2)])
print(t)
# Out:
# +-----------------------------------------+--------------+---------------+------------+------------+------------+
# |                                         | ZPAP Myszków | ZPAP Kotowiec | ZPAP Łapy  | ZPAP Wola  | ZPAP Rogi  |
# +-----------------------------------------+--------------+---------------+------------+------------+------------+
# | Liczba pras do łączenia detali (r)      |      6       |       4       |     9      |     2      |     5      |
# | Liczba elem. przychodzących na h (λ)    |     32.4     |      21.4     |   49.21    |    3.8     |    12.7    |
# | Liczba operacji na poj. prasie na h (μ) |     3.12     |      5.52     |    5.52    |    2.0     |    5.52    |
# | Wskaźnik intensywności ruchu ϱ=λ/(μ*r)  |     1.73     |      0.97     |    0.99    |    0.95    |    0.46    |
# | ----------                              |  ----------  |   ----------  | ---------- | ---------- | ---------- |
# ...

# %%
0.05*65
# Out:
# 3.25

# %%
16+8+4+2+1
# Out:
# 31
