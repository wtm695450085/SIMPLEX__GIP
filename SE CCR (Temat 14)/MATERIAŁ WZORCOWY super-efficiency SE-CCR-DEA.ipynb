# %% [markdown]
# ![obraz.png](attachment:obraz.png)

# %% [markdown]
# <span style="font-size: 150%;color:white;background:red"> MATERIAŁ WZORCOWY 2 CCR-DEA
#
# <span style="font-size: 160%;color:#0000ff"> PODSTAWOWE MOŻLIWOŚCI ANALITYCZNE MODELU CCR-DEA, Bogusław GUZIK

# %% [markdown]
# https://stackoverflow.com/questions/26004610/defining-constraints-for-dea-optimization-in-python

# %%
from beautifultable import BeautifulTable

table = BeautifulTable()
table.column_headers = ["Bank","B1","B2","B3","B4","B5","B6","B7","B8","B9","B10"]
table.append_row(["Majątek",626,466 ,98.7,242,1367,57.2,549,807,1.4,567])
table.append_row(["Wkład",13292,8762 ,5881,5449,51182,346,10560,31455,323,13170 ])
table.append_row(["Zatrudnienie",3997,2152,1250,645,40807,367,6939,25380,58,9363 ])
table.append_row(["Koszty",531,283,75.5,214,2102,32.9,536,900,14.2,476])
table.append_row(["Kredyty",9471,5859,1866,3540,17009,529,6761,7756,371,8027])
table.append_row(["Należności",2811,1200,3772,1807,3895,274,1162,5644,5,952])
print(table)
# Out:
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |   Bank    |  B1   |  B2  |  B3  |  B4  | B5  |  B6  | B7  | B8  |  B9  | B10 |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |  Majątek  |  626  | 466  | 98.7 | 242  | 136 | 57.2 | 549 | 807 | 1.4  | 567 |
# |           |       |      |      |      |  7  |      |     |     |      |     |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |   Wkład   | 13292 | 8762 | 5881 | 5449 | 511 | 346  | 105 | 314 | 323  | 131 |
# |           |       |      |      |      | 82  |      | 60  | 55  |      | 70  |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# | Zatrudnie | 3997  | 2152 | 1250 | 645  | 408 | 367  | 693 | 253 |  58  | 936 |
# |    nie    |       |      |      |      | 07  |      |  9  | 80  |      |  3  |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# ...

# %% [markdown]
# # Aby obliczyć wydajność D2

# %% [markdown]
# #### $
# \left\{
# \begin{align}
# {626x_{1}+466x_{2}+98.7x_{3}+242x_{4}+1367x_{5}+57.2x_{6}+549x_{7}+807x_{8}+1.4x_{9}+567x_{10}} & \leqslant 466θ_{2} & (1)\\
# {13292x_{1}+8762x_{2}+5881x_{3}+5449x_{4}+51182x_{5}+346x_{6}+10560x_{7}+31455x_{8}+323x_{9}+13170x_{10}} & \leqslant 8762θ_{2} & (2)\\
# {3997x_{1}+2152x_{2}+1250x_{3}+645x_{4}+40807x_{5}+367x_{6}+6939x_{7}+25380x_{8}+58x_{9}+9363x_{10}} & \leqslant 2152θ_{2} & (3)\\
# {531x_{1}+283x_{2}+75.5x_{3}+214x_{4}+2102x_{5}+32.9x_{6}+536x_{7}+900x_{8}+14.2x_{9}+476x_{10}} & \leqslant 283θ & (1)\\
# {9471x_{1}+5859x_{2}+1866x_{3}+3540x_{4}+17009x_{5}+529x_{6}+6761x_{7}+7756x_{8}+371x_{9}+8027x_{10}} & \geqslant 5859 & (1)\\
# {2811x_{1}+1200x_{2}+3772x_{3}+1807x_{4}+3895x_{5}+274x_{6}+1162x_{7}+5644x_{8}+ 5x_{9}+952x_{10}} & \geqslant 1200 & (1)\\
# θ_{2} & \leqslant 0
# \end{align}
# \right.
# $

# %% [markdown]
# #### $
# \left\{
# \begin{align}
#  {x_{1}}\geqslant 0 \\
#  {x_{2}}\geqslant 0 \\
# {x_{3}}\geqslant 0 \\
# {x_{4}}\geqslant 0 \\
# {x_{5}}\geqslant 0 \\
# {x_{6}}\geqslant 0 \\
# {x_{7}}\geqslant 0 \\
# {x_{8}}\geqslant 0 \\
# {x_{9}}\geqslant 0 \\
# {x_{10}}\geqslant 0 \\
# \end{align}
# \right.
# $

# %% [markdown]
# $x_{1}$ to wydajność Bank Handlowy (wyrażona jako ułamek)
#
# $x_{2}$ to wydajność BRE Bank (wyrażona jako ułamek)
#
# $x_{3}$ to wydajność BIG Bank (wyrażona jako ułamek)
#
# $x_{4}$ to wydajność Citibank (Poland) (wyrażona jako ułamek)
#
# $x_{5}$ to wydajność PKO BP (wyrażona jako ułamek)
#
# $x_{6}$ to wydajność Bank Gospodarstwa Krajowego (wyrażona jako ułamek)
#
# $x_{7}$ to wydajność Bank Śląski (wyrażona jako ułamek)
#
# $x_{8}$ to wydajność PeKaO S.A. (Poland) (wyrażona jako ułamek)
#
# $x_{9}$ to wydajność Opel Bank (wyrażona jako ułamek)
#
# $x_{10}$ to wydajność Bank Gospodarki Żywnościowej (Poland) (wyrażona jako ułamek)

# %% [markdown]
# <span style="font-size: 350%;color:white;background:#1155cc"> B1 </span>
# <span style="font-size: 350%;color:white;background:red">     Bank Handlowy

# %%
from pulp import *
from fractions import Fraction

# zdefiniowanie problemu- to jest taka platforma do wrzucania na nia wszystkiego

prob = LpProblem("DEA_B1",LpMinimize)

# %%
# "Continuous"
# "Integer"

x1=LpVariable("x1",lowBound=0,upBound=None, cat="Continuous")
x2=LpVariable("x2",lowBound=0,upBound=None, cat="Continuous")
x3=LpVariable("x3",lowBound=0,upBound=None, cat="Continuous")
x4=LpVariable("x4",lowBound=0,upBound=None, cat="Continuous")
x5=LpVariable("x5",lowBound=0,upBound=None, cat="Continuous")
x6=LpVariable("x6",lowBound=0,upBound=None, cat="Continuous")
x7=LpVariable("x7",lowBound=0,upBound=None, cat="Continuous")
x8=LpVariable("x8",lowBound=0,upBound=None, cat="Continuous")
x9=LpVariable("x9",lowBound=0,upBound=None, cat="Continuous")
x10=LpVariable("x10",lowBound=0,upBound=None, cat="Continuous")
θ1=LpVariable("θ1",lowBound=0,upBound=1, cat="Continuous")

# %% [markdown]
# ### Dodajemy do platformy funkcje celu
#
# Funkcja celu - maksymalizacja
#
# # $
# θ_{1}  \to min\\
# $

# %%
# objective function
prob += θ1, "Minimalizacja"

# %%
print(prob)
# Out:
# DEA_B1:
# MINIMIZE
# 1*θ1 + 0
# VARIABLES
# θ1 <= 1 Continuous

# %%
from beautifultable import BeautifulTable

table = BeautifulTable()
table.column_headers = ["Bank","B1","B2","B3","B4","B5","B6","B7","B8","B9","B10"]
table.append_row(["Majątek",626,466 ,98.7,242,1367,57.2,549,807,1.4,567])
table.append_row(["Wkład",13292,8762 ,5881,5449,51182,346,10560,31455,323,13170 ])
table.append_row(["Zatrudnienie",3997,2152,1250,645,40807,367,6939,25380,58,9363 ])
table.append_row(["Koszty",531,283,75.5,214,2102,32.9,536,900,14.2,476])
table.append_row(["Kredyty",9471,5859,1866,3540,17009,529,6761,7756,371,8027])
table.append_row(["Należności",2811,1200,3772,1807,3895,274,1162,5644,5,952])
print(table)
# Out:
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |   Bank    |  B1   |  B2  |  B3  |  B4  | B5  |  B6  | B7  | B8  |  B9  | B10 |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |  Majątek  |  626  | 466  | 98.7 | 242  | 136 | 57.2 | 549 | 807 | 1.4  | 567 |
# |           |       |      |      |      |  7  |      |     |     |      |     |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |   Wkład   | 13292 | 8762 | 5881 | 5449 | 511 | 346  | 105 | 314 | 323  | 131 |
# |           |       |      |      |      | 82  |      | 60  | 55  |      | 70  |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# | Zatrudnie | 3997  | 2152 | 1250 | 645  | 408 | 367  | 693 | 253 |  58  | 936 |
# |    nie    |       |      |      |      | 07  |      |  9  | 80  |      |  3  |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# ...

# %% [markdown]
# #### $
# \left\{
# \begin{align}
# {626x_{1}+466x_{2}+98.7x_{3}+242x_{4}+1367x_{5}+57.2x_{6}+549x_{7}+807x_{8}+1.4x_{9}+567x_{10}} & \leqslant 626θ_{1} & (1)\\
# {13292x_{1}+8762x_{2}+5881x_{3}+5449x_{4}+51182x_{5}+346x_{6}+10560x_{7}+31455x_{8}+323x_{9}+13170x_{10}} & \leqslant 13292θ_{1} & (2)\\
# {3997x_{1}+2152x_{2}+1250x_{3}+645x_{4}+40807x_{5}+367x_{6}+6939x_{7}+25380x_{8}+58x_{9}+9363x_{10}} & \leqslant  3997θ_{1} & (3)\\
# {531x_{1}+283x_{2}+75.5x_{3}+214x_{4}+2102x_{5}+32.9x_{6}+536x_{7}+900x_{8}+14.2x_{9}+476x_{10}} & \leqslant 531θ_{1} & (1)\\
# {9471x_{1}+5859x_{2}+1866x_{3}+3540x_{4}+17009x_{5}+529x_{6}+6761x_{7}+7756x_{8}+371x_{9}+8027x_{10}} & \geqslant 9471 & (1)\\
# {2811x_{1}+1200x_{2}+3772x_{3}+1807x_{4}+3895x_{5}+274x_{6}+1162x_{7}+5644x_{8}+ 5x_{9}+952x_{10}} & \geqslant 2811 & (1)\\
# θ_{1} & \leqslant 1
# \end{align}
# \right.
# $

# %%
𝑥1=0
# main constraints
prob += 626*𝑥1+466*𝑥2+98.7*𝑥3+242*𝑥4+1367*𝑥5+57.2*𝑥6+549*𝑥7+807*𝑥8+1.4*𝑥9+567*𝑥10 <=626*θ1

# %%
prob += 13292*𝑥1+8762*𝑥2+5881*𝑥3+5449*𝑥4+51182*𝑥5+346*𝑥6+10560*𝑥7+31455*𝑥8+323*𝑥9+13170*𝑥10 <=13292*θ1

# %%
prob += 3997*𝑥1+2152*𝑥2+1250*𝑥3+6454*x4+40807*𝑥5+367*𝑥6+6939*𝑥7+25380*𝑥8+58*𝑥9+9363*𝑥10 <=3997*θ1

# %%
prob += 531*𝑥1+283*𝑥2+75.5*𝑥3+214*𝑥4+2102*𝑥5+32.9*𝑥6+536*𝑥7+900*𝑥8+14.2*𝑥9+476*𝑥10 <=531*θ1

# %%
prob += 9471*𝑥1+5859*𝑥2+1866*𝑥3+3540*𝑥4+17009*𝑥5+529*𝑥6+6761*𝑥7+7756*𝑥8+371*𝑥9+8027*𝑥10 >=9471

# %%
prob += 2811*𝑥1+1200*𝑥2+3772*𝑥3+1807*𝑥4+3895*𝑥5+274*𝑥6+1162*𝑥7+5644*𝑥8+5*𝑥9+952*𝑥10 >=2811

# %%
print(prob)
# Out:
# DEA_B1:
# MINIMIZE
# 1*θ1 + 0
# SUBJECT TO
# _C1: 567 x10 + 466 x2 + 98.7 x3 + 242 x4 + 1367 x5 + 57.2 x6 + 549 x7 + 807 x8
#  + 1.4 x9 - 626 θ1 <= 0
#
# _C2: 13170 x10 + 8762 x2 + 5881 x3 + 5449 x4 + 51182 x5 + 346 x6 + 10560 x7
#  + 31455 x8 + 323 x9 - 13292 θ1 <= 0
#
# _C3: 9363 x10 + 2152 x2 + 1250 x3 + 6454 x4 + 40807 x5 + 367 x6 + 6939 x7
#  + 25380 x8 + 58 x9 - 3997 θ1 <= 0
#
# _C4: 476 x10 + 283 x2 + 75.5 x3 + 214 x4 + 2102 x5 + 32.9 x6 + 536 x7 + 900 x8
#  + 14.2 x9 - 531 θ1 <= 0
#
# _C5: 8027 x10 + 5859 x2 + 1866 x3 + 3540 x4 + 17009 x5 + 529 x6 + 6761 x7
#  + 7756 x8 + 371 x9 >= 9471
#
# _C6: 952 x10 + 1200 x2 + 3772 x3 + 1807 x4 + 3895 x5 + 274 x6 + 1162 x7
#  + 5644 x8 + 5 x9 >= 2811
#
# VARIABLES
# x10 Continuous
# x2 Continuous
# x3 Continuous
# x4 Continuous
# x5 Continuous
# x6 Continuous
# x7 Continuous
# x8 Continuous
# x9 Continuous
# θ1 <= 1 Continuous

# %%
print(prob)
# Out:
# DEA_B1:
# MINIMIZE
# 1*θ1 + 0
# SUBJECT TO
# _C1: 567 x10 + 466 x2 + 98.7 x3 + 242 x4 + 1367 x5 + 57.2 x6 + 549 x7 + 807 x8
#  + 1.4 x9 - 626 θ1 <= 0
#
# _C2: 13170 x10 + 8762 x2 + 5881 x3 + 5449 x4 + 51182 x5 + 346 x6 + 10560 x7
#  + 31455 x8 + 323 x9 - 13292 θ1 <= 0
#
# _C3: 9363 x10 + 2152 x2 + 1250 x3 + 6454 x4 + 40807 x5 + 367 x6 + 6939 x7
#  + 25380 x8 + 58 x9 - 3997 θ1 <= 0
#
# _C4: 476 x10 + 283 x2 + 75.5 x3 + 214 x4 + 2102 x5 + 32.9 x6 + 536 x7 + 900 x8
#  + 14.2 x9 - 531 θ1 <= 0
#
# _C5: 8027 x10 + 5859 x2 + 1866 x3 + 3540 x4 + 17009 x5 + 529 x6 + 6761 x7
#  + 7756 x8 + 371 x9 >= 9471
#
# _C6: 952 x10 + 1200 x2 + 3772 x3 + 1807 x4 + 3895 x5 + 274 x6 + 1162 x7
#  + 5644 x8 + 5 x9 >= 2811
#
# VARIABLES
# x10 Continuous
# x2 Continuous
# x3 Continuous
# x4 Continuous
# x5 Continuous
# x6 Continuous
# x7 Continuous
# x8 Continuous
# x9 Continuous
# θ1 <= 1 Continuous

# %% [markdown]
# ### Rozwiązanie problemu

# %%
print("prob.solve",prob.solve())
# status of the solution
print(f"Status: {LpStatus[prob.status]}")
# Out:
# prob.solve 1
# Status: Optimal

# %%
for v in prob.variables():
    print(f"{v.name} = {str(Fraction(v.varValue).limit_denominator())}")
# Out:
# x10 = 0
# x2 = 0
# x3 = 329679/651667
# x4 = 0
# x5 = 0
# x6 = 228718/77477
# x7 = 0
# x8 = 0
# x9 = 18774503/1000000
# θ1 = 351905/464926

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x9 = 18774503/1000000
x9
# Out:
# 18.774503

# %%
x3 = 329679/651667
x3
# Out:
# 0.5059010199994782

# %%
x6=228718/77477
x6
# Out:
# 2.952076100003872

# %%
B1 =351905/464926
B1
# Out:
# 0.7569053999991396

# %% [markdown]
# <span style="font-size: 150%;color:white;background:red">Wydajność B1 (Bank Handlowy) wynosi 0.756

# %%
# maximum value of the objective function
print(f"max (x11+x12+x13+x21+x22+x23+x31+x32+x33+x41+x42+x43) = {str(Fraction(value(prob.objective)).limit_denominator())}")
# Out:
# max (x11+x12+x13+x21+x22+x23+x31+x32+x33+x41+x42+x43) = 351905/464926

# %% [markdown]
# <span style="font-size: 350%;color:white;background:#1155cc"> B2 </span>
# <span style="font-size: 350%;color:white;background:red">     BRE Bank

# %%
from pulp import *
from fractions import Fraction

# zdefiniowanie problemu- to jest taka platforma do wrzucania na nia wszystkiego

prob = LpProblem("DEA_B2",LpMinimize)

# %%
# "Continuous"
# "Integer"

x1=LpVariable("x1",lowBound=0,upBound=None, cat="Continuous")
x2=LpVariable("x2",lowBound=0,upBound=None, cat="Continuous")
x3=LpVariable("x3",lowBound=0,upBound=None, cat="Continuous")
x4=LpVariable("x4",lowBound=0,upBound=None, cat="Continuous")
x5=LpVariable("x5",lowBound=0,upBound=None, cat="Continuous")
x6=LpVariable("x6",lowBound=0,upBound=None, cat="Continuous")
x7=LpVariable("x7",lowBound=0,upBound=None, cat="Continuous")
x8=LpVariable("x8",lowBound=0,upBound=None, cat="Continuous")
x9=LpVariable("x9",lowBound=0,upBound=None, cat="Continuous")
x10=LpVariable("x10",lowBound=0,upBound=None, cat="Continuous")
θ2=LpVariable("θ2",lowBound=0,upBound=1, cat="Continuous")

# %% [markdown]
# ### Dodajemy do platformy funkcje celu
#
# Funkcja celu - maksymalizacja Dorking
#
# # $
# θ_{2}  \to min\\
# $

# %%
# objective function
prob += θ2, "Minimalizacja"

# %%
print(prob)
# Out:
# DEA_B2:
# MINIMIZE
# 1*θ2 + 0
# VARIABLES
# θ2 <= 1 Continuous

# %% [markdown]
# #### $
# \left\{
# \begin{align}
# {626x_{1}+466x_{2}+98.7x_{3}+242x_{4}+1367x_{5}+57.2x_{6}+549x_{7}+807x_{8}+1.4x_{9}+567x_{10}} & \leqslant 466θ_{2} & (1)\\
# {13292x_{1}+8762x_{2}+5881x_{3}+5449x_{4}+51182x_{5}+346x_{6}+10560x_{7}+31455x_{8}+323x_{9}+13170x_{10}} & \leqslant 8762θ_{2} & (2)\\
# {3997x_{1}+2152x_{2}+1250x_{3}+645x_{4}+40807x_{5}+367x_{6}+6939x_{7}+25380x_{8}+58x_{9}+9363x_{10}} & \leqslant 2152θ_{2} & (3)\\
# {531x_{1}+283x_{2}+75.5x_{3}+214x_{4}+2102x_{5}+32.9x_{6}+536x_{7}+900x_{8}+14.2x_{9}+476x_{10}} & \leqslant 283θ_{2} & (1)\\
# {9471x_{1}+5859x_{2}+1866x_{3}+3540x_{4}+17009x_{5}+529x_{6}+6761x_{7}+7756x_{8}+371x_{9}+8027x_{10}} & \geqslant 5859 & (1)\\
# {2811x_{1}+1200x_{2}+3772x_{3}+1807x_{4}+3895x_{5}+274x_{6}+1162x_{7}+5644x_{8}+ 5x_{9}+952x_{10}} & \geqslant 1200 & (1)\\
# θ_{2} & \leqslant 1
# \end{align}
# \right.
# $

# %%
𝑥2 = 0

# main constraints
prob += 626*𝑥1+466*𝑥2+98.7*𝑥3+242*𝑥4+1367*𝑥5+57.2*𝑥6+549*𝑥7+807*𝑥8+1.4*𝑥9+567*𝑥10 <=466*θ2

# %%
prob += 13292*𝑥1+8762*𝑥2+5881*𝑥3+5449*𝑥4+51182*𝑥5+346*𝑥6+10560*𝑥7+31455*𝑥8+323*𝑥9+13170*𝑥10 <=8762*θ2

# %%
prob += 3997*𝑥1+2152*𝑥2+1250*𝑥3+6454*x4+40807*𝑥5+367*𝑥6+6939*𝑥7+25380*𝑥8+58*𝑥9+9363*𝑥10 <=2152*θ2

# %%
prob += 531*𝑥1+283*𝑥2+75.5*𝑥3+214*𝑥4+2102*𝑥5+32.9*𝑥6+536*𝑥7+900*𝑥8+14.2*𝑥9+476*𝑥10 <=283*θ2

# %%
prob += 9471*𝑥1+5859*𝑥2+1866*𝑥3+3540*𝑥4+17009*𝑥5+529*𝑥6+6761*𝑥7+7756*𝑥8+371*𝑥9+8027*𝑥10 >=5859

# %%
prob += 2811*𝑥1+1200*𝑥2+3772*𝑥3+1807*𝑥4+3895*𝑥5+274*𝑥6+1162*𝑥7+5644*𝑥8+5*𝑥9+952*𝑥10 >=1200

# %%
print(prob)
# Out:
# DEA_B2:
# MINIMIZE
# 1*θ2 + 0
# SUBJECT TO
# _C1: 626 x1 + 567 x10 + 98.7 x3 + 242 x4 + 1367 x5 + 57.2 x6 + 549 x7 + 807 x8
#  + 1.4 x9 - 466 θ2 <= 0
#
# _C2: 13292 x1 + 13170 x10 + 5881 x3 + 5449 x4 + 51182 x5 + 346 x6 + 10560 x7
#  + 31455 x8 + 323 x9 - 8762 θ2 <= 0
#
# _C3: 3997 x1 + 9363 x10 + 1250 x3 + 6454 x4 + 40807 x5 + 367 x6 + 6939 x7
#  + 25380 x8 + 58 x9 - 2152 θ2 <= 0
#
# _C4: 531 x1 + 476 x10 + 75.5 x3 + 214 x4 + 2102 x5 + 32.9 x6 + 536 x7 + 900 x8
#  + 14.2 x9 - 283 θ2 <= 0
#
# _C5: 9471 x1 + 8027 x10 + 1866 x3 + 3540 x4 + 17009 x5 + 529 x6 + 6761 x7
#  + 7756 x8 + 371 x9 >= 5859
#
# _C6: 2811 x1 + 952 x10 + 3772 x3 + 1807 x4 + 3895 x5 + 274 x6 + 1162 x7
#  + 5644 x8 + 5 x9 >= 1200
#
# VARIABLES
# x1 Continuous
# x10 Continuous
# x3 Continuous
# x4 Continuous
# x5 Continuous
# x6 Continuous
# x7 Continuous
# x8 Continuous
# x9 Continuous
# θ2 <= 1 Continuous

# %%
print(prob)
# Out:
# DEA_B2:
# MINIMIZE
# 1*θ2 + 0
# SUBJECT TO
# _C1: 626 x1 + 567 x10 + 98.7 x3 + 242 x4 + 1367 x5 + 57.2 x6 + 549 x7 + 807 x8
#  + 1.4 x9 - 466 θ2 <= 0
#
# _C2: 13292 x1 + 13170 x10 + 5881 x3 + 5449 x4 + 51182 x5 + 346 x6 + 10560 x7
#  + 31455 x8 + 323 x9 - 8762 θ2 <= 0
#
# _C3: 3997 x1 + 9363 x10 + 1250 x3 + 6454 x4 + 40807 x5 + 367 x6 + 6939 x7
#  + 25380 x8 + 58 x9 - 2152 θ2 <= 0
#
# _C4: 531 x1 + 476 x10 + 75.5 x3 + 214 x4 + 2102 x5 + 32.9 x6 + 536 x7 + 900 x8
#  + 14.2 x9 - 283 θ2 <= 0
#
# _C5: 9471 x1 + 8027 x10 + 1866 x3 + 3540 x4 + 17009 x5 + 529 x6 + 6761 x7
#  + 7756 x8 + 371 x9 >= 5859
#
# _C6: 2811 x1 + 952 x10 + 3772 x3 + 1807 x4 + 3895 x5 + 274 x6 + 1162 x7
#  + 5644 x8 + 5 x9 >= 1200
#
# VARIABLES
# x1 Continuous
# x10 Continuous
# x3 Continuous
# x4 Continuous
# x5 Continuous
# x6 Continuous
# x7 Continuous
# x8 Continuous
# x9 Continuous
# θ2 <= 1 Continuous

# %% [markdown]
# ### Rozwiązanie problemu

# %%
print("prob.solve",prob.solve())
# status of the solution
print(f"Status: {LpStatus[prob.status]}")
# Out:
# prob.solve 1
# Status: Optimal

# %%
for v in prob.variables():
    print(f"{v.name} = {str(Fraction(v.varValue).limit_denominator())}")
# Out:
# x1 = 0
# x10 = 0
# x3 = 269209/899779
# x4 = 0
# x5 = 0
# x6 = 0
# x7 = 0
# x8 = 0
# x9 = 14287609/1000000
# θ2 = 421721/529318

# %%
x3 = 269209/899779
x3
# Out:
# 0.2991945800024228

# %%
x9 = 14287609/1000000
x9
# Out:
# 14.287609

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
B2 = 421721/529318
B2
# Out:
# 0.7967252200000756

# %% [markdown]
# <span style="font-size: 150%;color:white;background:red">Wydajność B2 (BRE Bank) wynosi 0.797

# %%
# maximum value of the objective function
print(f"max (x11+x12+x13+x21+x22+x23+x31+x32+x33+x41+x42+x43) = {str(Fraction(value(prob.objective)).limit_denominator())}")
# Out:
# max (x11+x12+x13+x21+x22+x23+x31+x32+x33+x41+x42+x43) = 421721/529318

# %% [markdown]
# <span style="font-size: 350%;color:white;background:#1155cc"> B3 </span>
# <span style="font-size: 350%;color:white;background:red">     BIG Bank

# %%
from pulp import *
from fractions import Fraction

# zdefiniowanie problemu- to jest taka platforma do wrzucania na nia wszystkiego

prob = LpProblem("DEA_B3",LpMinimize)

# %%
# "Continuous"
# "Integer"

x1=LpVariable("x1",lowBound=0,upBound=None, cat="Continuous")
x2=LpVariable("x2",lowBound=0,upBound=None, cat="Continuous")
x3=LpVariable("x3",lowBound=0,upBound=None, cat="Continuous")
x4=LpVariable("x4",lowBound=0,upBound=None, cat="Continuous")
x5=LpVariable("x5",lowBound=0,upBound=None, cat="Continuous")
x6=LpVariable("x6",lowBound=0,upBound=None, cat="Continuous")
x7=LpVariable("x7",lowBound=0,upBound=None, cat="Continuous")
x8=LpVariable("x8",lowBound=0,upBound=None, cat="Continuous")
x9=LpVariable("x9",lowBound=0,upBound=None, cat="Continuous")
x10=LpVariable("x10",lowBound=0,upBound=None, cat="Continuous")
θ3=LpVariable("θ3",lowBound=0,upBound=1, cat="Continuous")

# %% [markdown]
# ### Dodajemy do platformy funkcje celu
#
# Funkcja celu - maksymalizacja
#
# # $
# θ_{3}  \to min\\
# $

# %%
# objective function
prob += θ3, "Minimalizacja"

# %%
print(prob)
# Out:
# DEA_B3:
# MINIMIZE
# 1*θ3 + 0
# VARIABLES
# θ3 <= 1 Continuous

# %%
from beautifultable import BeautifulTable

table = BeautifulTable()
table.column_headers = ["Bank","B1","B2","B3","B4","B5","B6","B7","B8","B9","B10"]
table.append_row(["Majątek",626,466 ,98.7,242,1367,57.2,549,807,1.4,567])
table.append_row(["Wkład",13292,8762 ,5881,5449,51182,346,10560,31455,323,13170 ])
table.append_row(["Zatrudnienie",3997,2152,1250,645,40807,367,6939,25380,58,9363 ])
table.append_row(["Koszty",531,283,75.5,214,2102,32.9,536,900,14.2,476])
table.append_row(["Kredyty",9471,5859,1866,3540,17009,529,6761,7756,371,8027])
table.append_row(["Należności",2811,1200,3772,1807,3895,274,1162,5644,5,952])
print(table)
# Out:
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |   Bank    |  B1   |  B2  |  B3  |  B4  | B5  |  B6  | B7  | B8  |  B9  | B10 |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |  Majątek  |  626  | 466  | 98.7 | 242  | 136 | 57.2 | 549 | 807 | 1.4  | 567 |
# |           |       |      |      |      |  7  |      |     |     |      |     |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |   Wkład   | 13292 | 8762 | 5881 | 5449 | 511 | 346  | 105 | 314 | 323  | 131 |
# |           |       |      |      |      | 82  |      | 60  | 55  |      | 70  |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# | Zatrudnie | 3997  | 2152 | 1250 | 645  | 408 | 367  | 693 | 253 |  58  | 936 |
# |    nie    |       |      |      |      | 07  |      |  9  | 80  |      |  3  |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# ...

# %% [markdown]
# #### $
# \left\{
# \begin{align}
# {626x_{1}+466x_{2}+98.7x_{3}+242x_{4}+1367x_{5}+57.2x_{6}+549x_{7}+807x_{8}+1.4x_{9}+567x_{10}} & \leqslant 98.7θ_{3} & (1)\\
# {13292x_{1}+8762x_{2}+5881x_{3}+5449x_{4}+51182x_{5}+346x_{6}+10560x_{7}+31455x_{8}+323x_{9}+13170x_{10}} & \leqslant 5881θ_{3} & (2)\\
# {3997x_{1}+2152x_{2}+1250x_{3}+645x_{4}+40807x_{5}+367x_{6}+6939x_{7}+25380x_{8}+58x_{9}+9363x_{10}} & \leqslant  1250θ_{3} & (3)\\
# {531x_{1}+283x_{2}+75.5x_{3}+214x_{4}+2102x_{5}+32.9x_{6}+536x_{7}+900x_{8}+14.2x_{9}+476x_{10}} & \leqslant 75.5θ_{3} & (1)\\
# {9471x_{1}+5859x_{2}+1866x_{3}+3540x_{4}+17009x_{5}+529x_{6}+6761x_{7}+7756x_{8}+371x_{9}+8027x_{10}} & \geqslant 1866 & (1)\\
# {2811x_{1}+1200x_{2}+3772x_{3}+1807x_{4}+3895x_{5}+274x_{6}+1162x_{7}+5644x_{8}+ 5x_{9}+952x_{10}} & \geqslant 3772 & (1)\\
# θ_{3} & \leqslant 1
# \end{align}
# \right.
# $

# %%
𝑥3 = 0
# main constraints
prob += 626*𝑥1+466*𝑥2+98.7*𝑥3+242*𝑥4+1367*𝑥5+57.2*𝑥6+549*𝑥7+807*𝑥8+1.4*𝑥9+567*𝑥10 <=98.7*θ3

# %%
prob += 13292*𝑥1+8762*𝑥2+5881*𝑥3+5449*𝑥4+51182*𝑥5+346*𝑥6+10560*𝑥7+31455*𝑥8+323*𝑥9+13170*𝑥10 <=5881*θ3

# %%
prob += 3997*𝑥1+2152*𝑥2+1250*𝑥3+6454*x4+40807*𝑥5+367*𝑥6+6939*𝑥7+25380*𝑥8+58*𝑥9+9363*𝑥10 <=1250*θ3

# %%
prob += 531*𝑥1+283*𝑥2+75.5*𝑥3+214*𝑥4+2102*𝑥5+32.9*𝑥6+536*𝑥7+900*𝑥8+14.2*𝑥9+476*𝑥10 <=75.5*θ3

# %%
prob += 9471*𝑥1+5859*𝑥2+1866*𝑥3+3540*𝑥4+17009*𝑥5+529*𝑥6+6761*𝑥7+7756*𝑥8+371*𝑥9+8027*𝑥10 >=1866

# %%
prob += 2811*𝑥1+1200*𝑥2+3772*𝑥3+1807*𝑥4+3895*𝑥5+274*𝑥6+1162*𝑥7+5644*𝑥8+5*𝑥9+952*𝑥10 >=3772

# %%
print(prob)
# Out:
# DEA_B3:
# MINIMIZE
# 1*θ3 + 0
# SUBJECT TO
# _C1: 626 x1 + 567 x10 + 466 x2 + 242 x4 + 1367 x5 + 57.2 x6 + 549 x7 + 807 x8
#  + 1.4 x9 - 98.7 θ3 <= 0
#
# _C2: 13292 x1 + 13170 x10 + 8762 x2 + 5449 x4 + 51182 x5 + 346 x6 + 10560 x7
#  + 31455 x8 + 323 x9 - 5881 θ3 <= 0
#
# _C3: 3997 x1 + 9363 x10 + 2152 x2 + 6454 x4 + 40807 x5 + 367 x6 + 6939 x7
#  + 25380 x8 + 58 x9 - 1250 θ3 <= 0
#
# _C4: 531 x1 + 476 x10 + 283 x2 + 214 x4 + 2102 x5 + 32.9 x6 + 536 x7 + 900 x8
#  + 14.2 x9 - 75.5 θ3 <= 0
#
# _C5: 9471 x1 + 8027 x10 + 5859 x2 + 3540 x4 + 17009 x5 + 529 x6 + 6761 x7
#  + 7756 x8 + 371 x9 >= 1866
#
# _C6: 2811 x1 + 952 x10 + 1200 x2 + 1807 x4 + 3895 x5 + 274 x6 + 1162 x7
#  + 5644 x8 + 5 x9 >= 3772
#
# VARIABLES
# x1 Continuous
# x10 Continuous
# x2 Continuous
# x4 Continuous
# x5 Continuous
# x6 Continuous
# x7 Continuous
# x8 Continuous
# x9 Continuous
# θ3 <= 1 Continuous

# %%
print(prob)
# Out:
# DEA_B3:
# MINIMIZE
# 1*θ3 + 0
# SUBJECT TO
# _C1: 626 x1 + 567 x10 + 466 x2 + 242 x4 + 1367 x5 + 57.2 x6 + 549 x7 + 807 x8
#  + 1.4 x9 - 98.7 θ3 <= 0
#
# _C2: 13292 x1 + 13170 x10 + 8762 x2 + 5449 x4 + 51182 x5 + 346 x6 + 10560 x7
#  + 31455 x8 + 323 x9 - 5881 θ3 <= 0
#
# _C3: 3997 x1 + 9363 x10 + 2152 x2 + 6454 x4 + 40807 x5 + 367 x6 + 6939 x7
#  + 25380 x8 + 58 x9 - 1250 θ3 <= 0
#
# _C4: 531 x1 + 476 x10 + 283 x2 + 214 x4 + 2102 x5 + 32.9 x6 + 536 x7 + 900 x8
#  + 14.2 x9 - 75.5 θ3 <= 0
#
# _C5: 9471 x1 + 8027 x10 + 5859 x2 + 3540 x4 + 17009 x5 + 529 x6 + 6761 x7
#  + 7756 x8 + 371 x9 >= 1866
#
# _C6: 2811 x1 + 952 x10 + 1200 x2 + 1807 x4 + 3895 x5 + 274 x6 + 1162 x7
#  + 5644 x8 + 5 x9 >= 3772
#
# VARIABLES
# x1 Continuous
# x10 Continuous
# x2 Continuous
# x4 Continuous
# x5 Continuous
# x6 Continuous
# x7 Continuous
# x8 Continuous
# x9 Continuous
# θ3 <= 1 Continuous

# %% [markdown]
# ### Rozwiązanie problemu

# %%
print("prob.solve",prob.solve())
# status of the solution
print(f"Status: {LpStatus[prob.status]}")
# Out:
# prob.solve -1
# Status: Infeasible

# %%
for v in prob.variables():
    print(f"{v.name} = {str(Fraction(v.varValue).limit_denominator())}")
# Out:
# x1 = 0
# x10 = 0
# x2 = 0
# x4 = 751518/877667
# x5 = 0
# x6 = 2088139/257178
# x7 = 0
# x8 = 0
# x9 = 0
# θ3 = 1246292/183145

# %% [markdown]
# <span style="font-size: 150%;color:white;background:red">Wydajność B3 (BIG Bank ) wynosi 100%

# %%
# maximum value of the objective function
print(f"max (x11+x12+x13+x21+x22+x23+x31+x32+x33+x41+x42+x43) = {str(Fraction(value(prob.objective)).limit_denominator())}")
# Out:
# max (x11+x12+x13+x21+x22+x23+x31+x32+x33+x41+x42+x43) = 1246292/183145

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x4 = 751518/877667
x4
# Out:
# 0.8562678100008317

# %%
x6 = 2088139/257178
x6
# Out:
# 8.119430899999223

# %%
B3=1246292/183145
B3
# Out:
# 6.80494689999727

# %% [markdown]
# <span style="font-size: 350%;color:white;background:#1155cc"> B4 </span>
# <span style="font-size: 350%;color:white;background:red">     Citibank

# %%
from pulp import *
from fractions import Fraction

# zdefiniowanie problemu- to jest taka platforma do wrzucania na nia wszystkiego

prob = LpProblem("DEA_B4",LpMinimize)

# %%
# "Continuous"
# "Integer"

x1=LpVariable("x1",lowBound=0,upBound=None, cat="Continuous")
x2=LpVariable("x2",lowBound=0,upBound=None, cat="Continuous")
x3=LpVariable("x3",lowBound=0,upBound=None, cat="Continuous")
x4=LpVariable("x4",lowBound=0,upBound=None, cat="Continuous")
x5=LpVariable("x5",lowBound=0,upBound=None, cat="Continuous")
x6=LpVariable("x6",lowBound=0,upBound=None, cat="Continuous")
x7=LpVariable("x7",lowBound=0,upBound=None, cat="Continuous")
x8=LpVariable("x8",lowBound=0,upBound=None, cat="Continuous")
x9=LpVariable("x9",lowBound=0,upBound=None, cat="Continuous")
x10=LpVariable("x10",lowBound=0,upBound=None, cat="Continuous")
θ4=LpVariable("θ4",lowBound=0,upBound=1, cat="Continuous")

# %% [markdown]
# ### Dodajemy do platformy funkcje celu
#
# Funkcja celu - maksymalizacja
#
# # $
# θ_{4}  \to min\\
# $

# %%
# objective function
prob += θ4, "Minimalizacja"

# %%
print(prob)
# Out:
# DEA_B4:
# MINIMIZE
# 1*θ4 + 0
# VARIABLES
# θ4 <= 1 Continuous

# %%
from beautifultable import BeautifulTable

table = BeautifulTable()
table.column_headers = ["Bank","B1","B2","B3","B4","B5","B6","B7","B8","B9","B10"]
table.append_row(["Majątek",626,466 ,98.7,242,1367,57.2,549,807,1.4,567])
table.append_row(["Wkład",13292,8762 ,5881,5449,51182,346,10560,31455,323,13170 ])
table.append_row(["Zatrudnienie",3997,2152,1250,645,40807,367,6939,25380,58,9363 ])
table.append_row(["Koszty",531,283,75.5,214,2102,32.9,536,900,14.2,476])
table.append_row(["Kredyty",9471,5859,1866,3540,17009,529,6761,7756,371,8027])
table.append_row(["Należności",2811,1200,3772,1807,3895,274,1162,5644,5,952])
print(table)
# Out:
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |   Bank    |  B1   |  B2  |  B3  |  B4  | B5  |  B6  | B7  | B8  |  B9  | B10 |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |  Majątek  |  626  | 466  | 98.7 | 242  | 136 | 57.2 | 549 | 807 | 1.4  | 567 |
# |           |       |      |      |      |  7  |      |     |     |      |     |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |   Wkład   | 13292 | 8762 | 5881 | 5449 | 511 | 346  | 105 | 314 | 323  | 131 |
# |           |       |      |      |      | 82  |      | 60  | 55  |      | 70  |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# | Zatrudnie | 3997  | 2152 | 1250 | 645  | 408 | 367  | 693 | 253 |  58  | 936 |
# |    nie    |       |      |      |      | 07  |      |  9  | 80  |      |  3  |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# ...

# %% [markdown]
# #### $
# \left\{
# \begin{align}
# {626x_{1}+466x_{2}+98.7x_{3}+242x_{4}+1367x_{5}+57.2x_{6}+549x_{7}+807x_{8}+1.4x_{9}+567x_{10}} & \leqslant 242θ_{4} & (1)\\
# {13292x_{1}+8762x_{2}+5881x_{3}+5449x_{4}+51182x_{5}+346x_{6}+10560x_{7}+31455x_{8}+323x_{9}+13170x_{10}} & \leqslant 5449θ_{4} & (2)\\
# {3997x_{1}+2152x_{2}+1250x_{3}+645x_{4}+40807x_{5}+367x_{6}+6939x_{7}+25380x_{8}+58x_{9}+9363x_{10}} & \leqslant  645θ_{4} & (3)\\
# {531x_{1}+283x_{2}+75.5x_{3}+214x_{4}+2102x_{5}+32.9x_{6}+536x_{7}+900x_{8}+14.2x_{9}+476x_{10}} & \leqslant 214θ_{4} & (1)\\
# {9471x_{1}+5859x_{2}+1866x_{3}+3540x_{4}+17009x_{5}+529x_{6}+6761x_{7}+7756x_{8}+371x_{9}+8027x_{10}} & \geqslant 3540 & (1)\\
# {2811x_{1}+1200x_{2}+3772x_{3}+1807x_{4}+3895x_{5}+274x_{6}+1162x_{7}+5644x_{8}+ 5x_{9}+952x_{10}} & \geqslant 1807 & (1)\\
# θ_{4} & \leqslant 1
# \end{align}
# \right.
# $

# %%
𝑥4 = 0

# main constraints
prob += 626*𝑥1+466*𝑥2+98.7*𝑥3+242*𝑥4+1367*𝑥5+57.2*𝑥6+549*𝑥7+807*𝑥8+1.4*𝑥9+567*𝑥10 <=242*θ4

# %%
prob += 13292*𝑥1+8762*𝑥2+5881*𝑥3+5449*𝑥4+51182*𝑥5+346*𝑥6+10560*𝑥7+31455*𝑥8+323*𝑥9+13170*𝑥10 <=5449*θ4

# %%
prob += 3997*𝑥1+2152*𝑥2+1250*𝑥3+6454*x4+40807*𝑥5+367*𝑥6+6939*𝑥7+25380*𝑥8+58*𝑥9+9363*𝑥10 <=645*θ4

# %%
prob += 531*𝑥1+283*𝑥2+75.5*𝑥3+214*𝑥4+2102*𝑥5+32.9*𝑥6+536*𝑥7+900*𝑥8+14.2*𝑥9+476*𝑥10 <=214*θ4

# %%
prob += 9471*𝑥1+5859*𝑥2+1866*𝑥3+3540*𝑥4+17009*𝑥5+529*𝑥6+6761*𝑥7+7756*𝑥8+371*𝑥9+8027*𝑥10 >=3540

# %%
prob += 2811*𝑥1+1200*𝑥2+3772*𝑥3+1807*𝑥4+3895*𝑥5+274*𝑥6+1162*𝑥7+5644*𝑥8+5*𝑥9+952*𝑥10 >=1807

# %%
print(prob)
# Out:
# DEA_B4:
# MINIMIZE
# 1*θ4 + 0
# SUBJECT TO
# _C1: 626 x1 + 567 x10 + 466 x2 + 98.7 x3 + 1367 x5 + 57.2 x6 + 549 x7 + 807 x8
#  + 1.4 x9 - 242 θ4 <= 0
#
# _C2: 13292 x1 + 13170 x10 + 8762 x2 + 5881 x3 + 51182 x5 + 346 x6 + 10560 x7
#  + 31455 x8 + 323 x9 - 5449 θ4 <= 0
#
# _C3: 3997 x1 + 9363 x10 + 2152 x2 + 1250 x3 + 40807 x5 + 367 x6 + 6939 x7
#  + 25380 x8 + 58 x9 - 645 θ4 <= 0
#
# _C4: 531 x1 + 476 x10 + 283 x2 + 75.5 x3 + 2102 x5 + 32.9 x6 + 536 x7 + 900 x8
#  + 14.2 x9 - 214 θ4 <= 0
#
# _C5: 9471 x1 + 8027 x10 + 5859 x2 + 1866 x3 + 17009 x5 + 529 x6 + 6761 x7
#  + 7756 x8 + 371 x9 >= 3540
#
# _C6: 2811 x1 + 952 x10 + 1200 x2 + 3772 x3 + 3895 x5 + 274 x6 + 1162 x7
#  + 5644 x8 + 5 x9 >= 1807
#
# VARIABLES
# x1 Continuous
# x10 Continuous
# x2 Continuous
# x3 Continuous
# x5 Continuous
# x6 Continuous
# x7 Continuous
# x8 Continuous
# x9 Continuous
# θ4 <= 1 Continuous

# %%
print(prob)
# Out:
# DEA_B4:
# MINIMIZE
# 1*θ4 + 0
# SUBJECT TO
# _C1: 626 x1 + 567 x10 + 466 x2 + 98.7 x3 + 1367 x5 + 57.2 x6 + 549 x7 + 807 x8
#  + 1.4 x9 - 242 θ4 <= 0
#
# _C2: 13292 x1 + 13170 x10 + 8762 x2 + 5881 x3 + 51182 x5 + 346 x6 + 10560 x7
#  + 31455 x8 + 323 x9 - 5449 θ4 <= 0
#
# _C3: 3997 x1 + 9363 x10 + 2152 x2 + 1250 x3 + 40807 x5 + 367 x6 + 6939 x7
#  + 25380 x8 + 58 x9 - 645 θ4 <= 0
#
# _C4: 531 x1 + 476 x10 + 283 x2 + 75.5 x3 + 2102 x5 + 32.9 x6 + 536 x7 + 900 x8
#  + 14.2 x9 - 214 θ4 <= 0
#
# _C5: 9471 x1 + 8027 x10 + 5859 x2 + 1866 x3 + 17009 x5 + 529 x6 + 6761 x7
#  + 7756 x8 + 371 x9 >= 3540
#
# _C6: 2811 x1 + 952 x10 + 1200 x2 + 3772 x3 + 3895 x5 + 274 x6 + 1162 x7
#  + 5644 x8 + 5 x9 >= 1807
#
# VARIABLES
# x1 Continuous
# x10 Continuous
# x2 Continuous
# x3 Continuous
# x5 Continuous
# x6 Continuous
# x7 Continuous
# x8 Continuous
# x9 Continuous
# θ4 <= 1 Continuous

# %% [markdown]
# ### Rozwiązanie problemu

# %%
print("prob.solve",prob.solve())
# status of the solution
print(f"Status: {LpStatus[prob.status]}")
# Out:
# prob.solve -1
# Status: Infeasible

# %%
for v in prob.variables():
    print(f"{v.name} = {str(Fraction(v.varValue).limit_denominator())}")
# Out:
# x1 = 0
# x10 = 0
# x2 = 0
# x3 = 466995/994583
# x5 = 0
# x6 = 0
# x7 = 0
# x8 = 0
# x9 = 2865970/399151
# θ4 = 110609/71103

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x3 = 466995/994583
x3
# Out:
# 0.4695384900003318

# %%
x9 = 2865970/399151
x9
# Out:
# 7.180164900000251

# %% [markdown]
# <span style="font-size: 150%;color:white;background:red">Wydajność B4 (Citibank) wynosi 100%

# %%
# maximum value of the objective function
print(f"max (x11+x12+x13+x21+x22+x23+x31+x32+x33+x41+x42+x43) = {str(Fraction(value(prob.objective)).limit_denominator())}")
# Out:
# max (x11+x12+x13+x21+x22+x23+x31+x32+x33+x41+x42+x43) = 110609/71103

# %%
B4 = 110609/71103
B4
# Out:
# 1.555616500007032

# %% [markdown]
# <span style="font-size: 350%;color:white;background:#1155cc"> B5 </span>
# <span style="font-size: 350%;color:white;background:red">     PKO BP

# %%
from pulp import *
from fractions import Fraction

# zdefiniowanie problemu- to jest taka platforma do wrzucania na nia wszystkiego

prob = LpProblem("DEA_B5",LpMinimize)

# %%
# "Continuous"
# "Integer"

x1=LpVariable("x1",lowBound=0,upBound=None, cat="Continuous")
x2=LpVariable("x2",lowBound=0,upBound=None, cat="Continuous")
x3=LpVariable("x3",lowBound=0,upBound=None, cat="Continuous")
x4=LpVariable("x4",lowBound=0,upBound=None, cat="Continuous")
x5=LpVariable("x5",lowBound=0,upBound=None, cat="Continuous")
x6=LpVariable("x6",lowBound=0,upBound=None, cat="Continuous")
x7=LpVariable("x7",lowBound=0,upBound=None, cat="Continuous")
x8=LpVariable("x8",lowBound=0,upBound=None, cat="Continuous")
x9=LpVariable("x9",lowBound=0,upBound=None, cat="Continuous")
x10=LpVariable("x10",lowBound=0,upBound=None, cat="Continuous")
θ5=LpVariable("θ5",lowBound=0,upBound=1, cat="Continuous")

# %% [markdown]
# ### Dodajemy do platformy funkcje celu
#
# Funkcja celu - maksymalizacja
#
# # $
# θ_{5}  \to min\\
# $

# %%
# objective function
prob += θ5, "Minimalizacja"

# %%
print(prob)
# Out:
# DEA_B5:
# MINIMIZE
# 1*θ5 + 0
# VARIABLES
# θ5 <= 1 Continuous

# %%
from beautifultable import BeautifulTable

table = BeautifulTable()
table.column_headers = ["Bank","B1","B2","B3","B4","B5","B6","B7","B8","B9","B10"]
table.append_row(["Majątek",626,466 ,98.7,242,1367,57.2,549,807,1.4,567])
table.append_row(["Wkład",13292,8762 ,5881,5449,51182,346,10560,31455,323,13170 ])
table.append_row(["Zatrudnienie",3997,2152,1250,645,40807,367,6939,25380,58,9363 ])
table.append_row(["Koszty",531,283,75.5,214,2102,32.9,536,900,14.2,476])
table.append_row(["Kredyty",9471,5859,1866,3540,17009,529,6761,7756,371,8027])
table.append_row(["Należności",2811,1200,3772,1807,3895,274,1162,5644,5,952])
print(table)
# Out:
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |   Bank    |  B1   |  B2  |  B3  |  B4  | B5  |  B6  | B7  | B8  |  B9  | B10 |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |  Majątek  |  626  | 466  | 98.7 | 242  | 136 | 57.2 | 549 | 807 | 1.4  | 567 |
# |           |       |      |      |      |  7  |      |     |     |      |     |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |   Wkład   | 13292 | 8762 | 5881 | 5449 | 511 | 346  | 105 | 314 | 323  | 131 |
# |           |       |      |      |      | 82  |      | 60  | 55  |      | 70  |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# | Zatrudnie | 3997  | 2152 | 1250 | 645  | 408 | 367  | 693 | 253 |  58  | 936 |
# |    nie    |       |      |      |      | 07  |      |  9  | 80  |      |  3  |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# ...

# %% [markdown]
# #### $
# \left\{
# \begin{align}
# {626x_{1}+466x_{2}+98.7x_{3}+242x_{4}+1367x_{5}+57.2x_{6}+549x_{7}+807x_{8}+1.4x_{9}+567x_{10}} & \leqslant 1367θ_{5} & (1)\\
# {13292x_{1}+8762x_{2}+5881x_{3}+5449x_{4}+51182x_{5}+346x_{6}+10560x_{7}+31455x_{8}+323x_{9}+13170x_{10}} & \leqslant 51182θ_{5} & (2)\\
# {3997x_{1}+2152x_{2}+1250x_{3}+645x_{4}+40807x_{5}+367x_{6}+6939x_{7}+25380x_{8}+58x_{9}+9363x_{10}} & \leqslant  40807θ_{5} & (3)\\
# {531x_{1}+283x_{2}+75.5x_{3}+214x_{4}+2102x_{5}+32.9x_{6}+536x_{7}+900x_{8}+14.2x_{9}+476x_{10}} & \leqslant 2102θ_{5} & (1)\\
# {9471x_{1}+5859x_{2}+1866x_{3}+3540x_{4}+17009x_{5}+529x_{6}+6761x_{7}+7756x_{8}+371x_{9}+8027x_{10}} & \geqslant 17009 & (1)\\
# {2811x_{1}+1200x_{2}+3772x_{3}+1807x_{4}+3895x_{5}+274x_{6}+1162x_{7}+5644x_{8}+ 5x_{9}+952x_{10}} & \geqslant 3895 & (1)\\
# θ_{5} & \leqslant 1
# \end{align}
# \right.
# $

# %%
x5 = 0

# main constraints
prob += 626*𝑥1+466*𝑥2+98.7*𝑥3+242*𝑥4+1367*𝑥5+57.2*𝑥6+549*𝑥7+807*𝑥8+1.4*𝑥9+567*𝑥10 <=1367*θ5

# %%
prob += 13292*𝑥1+8762*𝑥2+5881*𝑥3+5449*𝑥4+51182*𝑥5+346*𝑥6+10560*𝑥7+31455*𝑥8+323*𝑥9+13170*𝑥10 <=51182*θ5

# %%
prob += 3997*𝑥1+2152*𝑥2+1250*𝑥3+6454*x4+40807*𝑥5+367*𝑥6+6939*𝑥7+25380*𝑥8+58*𝑥9+9363*𝑥10 <=40807*θ5

# %%
prob += 531*𝑥1+283*𝑥2+75.5*𝑥3+214*𝑥4+2102*𝑥5+32.9*𝑥6+536*𝑥7+900*𝑥8+14.2*𝑥9+476*𝑥10 <=2102*θ5

# %%
prob += 9471*𝑥1+5859*𝑥2+1866*𝑥3+3540*𝑥4+17009*𝑥5+529*𝑥6+6761*𝑥7+7756*𝑥8+371*𝑥9+8027*𝑥10 >=17009

# %%
prob += 2811*𝑥1+1200*𝑥2+3772*𝑥3+1807*𝑥4+3895*𝑥5+274*𝑥6+1162*𝑥7+5644*𝑥8+5*𝑥9+952*𝑥10 >=3895

# %%
print(prob)
# Out:
# DEA_B5:
# MINIMIZE
# 1*θ5 + 0
# SUBJECT TO
# _C1: 626 x1 + 567 x10 + 466 x2 + 98.7 x3 + 242 x4 + 57.2 x6 + 549 x7 + 807 x8
#  + 1.4 x9 - 1367 θ5 <= 0
#
# _C2: 13292 x1 + 13170 x10 + 8762 x2 + 5881 x3 + 5449 x4 + 346 x6 + 10560 x7
#  + 31455 x8 + 323 x9 - 51182 θ5 <= 0
#
# _C3: 3997 x1 + 9363 x10 + 2152 x2 + 1250 x3 + 6454 x4 + 367 x6 + 6939 x7
#  + 25380 x8 + 58 x9 - 40807 θ5 <= 0
#
# _C4: 531 x1 + 476 x10 + 283 x2 + 75.5 x3 + 214 x4 + 32.9 x6 + 536 x7 + 900 x8
#  + 14.2 x9 - 2102 θ5 <= 0
#
# _C5: 9471 x1 + 8027 x10 + 5859 x2 + 1866 x3 + 3540 x4 + 529 x6 + 6761 x7
#  + 7756 x8 + 371 x9 >= 17009
#
# _C6: 2811 x1 + 952 x10 + 1200 x2 + 3772 x3 + 1807 x4 + 274 x6 + 1162 x7
#  + 5644 x8 + 5 x9 >= 3895
#
# VARIABLES
# x1 Continuous
# x10 Continuous
# x2 Continuous
# x3 Continuous
# x4 Continuous
# x6 Continuous
# x7 Continuous
# x8 Continuous
# x9 Continuous
# θ5 <= 1 Continuous

# %%
print(prob)
# Out:
# DEA_B5:
# MINIMIZE
# 1*θ5 + 0
# SUBJECT TO
# _C1: 626 x1 + 567 x10 + 466 x2 + 98.7 x3 + 242 x4 + 57.2 x6 + 549 x7 + 807 x8
#  + 1.4 x9 - 1367 θ5 <= 0
#
# _C2: 13292 x1 + 13170 x10 + 8762 x2 + 5881 x3 + 5449 x4 + 346 x6 + 10560 x7
#  + 31455 x8 + 323 x9 - 51182 θ5 <= 0
#
# _C3: 3997 x1 + 9363 x10 + 2152 x2 + 1250 x3 + 6454 x4 + 367 x6 + 6939 x7
#  + 25380 x8 + 58 x9 - 40807 θ5 <= 0
#
# _C4: 531 x1 + 476 x10 + 283 x2 + 75.5 x3 + 214 x4 + 32.9 x6 + 536 x7 + 900 x8
#  + 14.2 x9 - 2102 θ5 <= 0
#
# _C5: 9471 x1 + 8027 x10 + 5859 x2 + 1866 x3 + 3540 x4 + 529 x6 + 6761 x7
#  + 7756 x8 + 371 x9 >= 17009
#
# _C6: 2811 x1 + 952 x10 + 1200 x2 + 3772 x3 + 1807 x4 + 274 x6 + 1162 x7
#  + 5644 x8 + 5 x9 >= 3895
#
# VARIABLES
# x1 Continuous
# x10 Continuous
# x2 Continuous
# x3 Continuous
# x4 Continuous
# x6 Continuous
# x7 Continuous
# x8 Continuous
# x9 Continuous
# θ5 <= 1 Continuous

# %% [markdown]
# ### Rozwiązanie problemu

# %%
print("prob.solve",prob.solve())
# status of the solution
print(f"Status: {LpStatus[prob.status]}")
# Out:
# prob.solve 1
# Status: Optimal

# %%
for v in prob.variables():
    print(f"{v.name} = {str(Fraction(v.varValue).limit_denominator())}")
# Out:
# x1 = 0
# x10 = 0
# x2 = 0
# x3 = 382699/563863
# x4 = 0
# x6 = 3143049/747086
# x7 = 0
# x8 = 0
# x9 = 113856/3125
# θ5 = 110963/329899

# %% [markdown]
# <span style="font-size: 150%;color:white;background:red">Wydajność B5 (PKO BP ) wynosi 0.336

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x3 = 382699/563863
x3
# Out:
# 0.6787091899982797

# %%
x6 = 3143049/747086
x6
# Out:
# 4.207077900000803

# %%
x9 = 113856/3125
x9
# Out:
# 36.43392

# %%
B5 = 110963/329899
B5
# Out:
# 0.33635446000139435

# %%
# maximum value of the objective function
print(f"max (x11+x12+x13+x21+x22+x23+x31+x32+x33+x41+x42+x43) = {str(Fraction(value(prob.objective)).limit_denominator())}")
# Out:
# max (x11+x12+x13+x21+x22+x23+x31+x32+x33+x41+x42+x43) = 110963/329899

# %% [markdown]
# <span style="font-size: 350%;color:white;background:#1155cc"> B6 </span>
# <span style="font-size: 350%;color:white;background:red">     Bank Gospodarstwa Krajowego

# %%
from pulp import *
from fractions import Fraction

# zdefiniowanie problemu- to jest taka platforma do wrzucania na nia wszystkiego

prob = LpProblem("DEA_B6",LpMinimize)

# %%
# "Continuous"
# "Integer"

x1=LpVariable("x1",lowBound=0,upBound=None, cat="Continuous")
x2=LpVariable("x2",lowBound=0,upBound=None, cat="Continuous")
x3=LpVariable("x3",lowBound=0,upBound=None, cat="Continuous")
x4=LpVariable("x4",lowBound=0,upBound=None, cat="Continuous")
x5=LpVariable("x5",lowBound=0,upBound=None, cat="Continuous")
x6=LpVariable("x6",lowBound=0,upBound=None, cat="Continuous")
x7=LpVariable("x7",lowBound=0,upBound=None, cat="Continuous")
x8=LpVariable("x8",lowBound=0,upBound=None, cat="Continuous")
x9=LpVariable("x9",lowBound=0,upBound=None, cat="Continuous")
x10=LpVariable("x10",lowBound=0,upBound=None, cat="Continuous")
θ6=LpVariable("θ6",lowBound=0,upBound=1, cat="Continuous")

# %% [markdown]
# ### Dodajemy do platformy funkcje celu
#
# Funkcja celu - maksymalizacja
#
# # $
# θ_{6}  \to min\\
# $

# %%
# objective function
prob += θ6, "Minimalizacja"

# %%
print(prob)
# Out:
# DEA_B6:
# MINIMIZE
# 1*θ6 + 0
# VARIABLES
# θ6 <= 1 Continuous

# %%
from beautifultable import BeautifulTable

table = BeautifulTable()
table.column_headers = ["Bank","B1","B2","B3","B4","B5","B6","B7","B8","B9","B10"]
table.append_row(["Majątek",626,466 ,98.7,242,1367,57.2,549,807,1.4,567])
table.append_row(["Wkład",13292,8762 ,5881,5449,51182,346,10560,31455,323,13170 ])
table.append_row(["Zatrudnienie",3997,2152,1250,645,40807,367,6939,25380,58,9363 ])
table.append_row(["Koszty",531,283,75.5,214,2102,32.9,536,900,14.2,476])
table.append_row(["Kredyty",9471,5859,1866,3540,17009,529,6761,7756,371,8027])
table.append_row(["Należności",2811,1200,3772,1807,3895,274,1162,5644,5,952])
print(table)
# Out:
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |   Bank    |  B1   |  B2  |  B3  |  B4  | B5  |  B6  | B7  | B8  |  B9  | B10 |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |  Majątek  |  626  | 466  | 98.7 | 242  | 136 | 57.2 | 549 | 807 | 1.4  | 567 |
# |           |       |      |      |      |  7  |      |     |     |      |     |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |   Wkład   | 13292 | 8762 | 5881 | 5449 | 511 | 346  | 105 | 314 | 323  | 131 |
# |           |       |      |      |      | 82  |      | 60  | 55  |      | 70  |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# | Zatrudnie | 3997  | 2152 | 1250 | 645  | 408 | 367  | 693 | 253 |  58  | 936 |
# |    nie    |       |      |      |      | 07  |      |  9  | 80  |      |  3  |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# ...

# %% [markdown]
# #### $
# \left\{
# \begin{align}
# {626x_{1}+466x_{2}+98.7x_{3}+242x_{4}+1367x_{5}+57.2x_{6}+549x_{7}+807x_{8}+1.4x_{9}+567x_{10}} & \leqslant 57.2θ_{6} & (1)\\
# {13292x_{1}+8762x_{2}+5881x_{3}+5449x_{4}+51182x_{5}+346x_{6}+10560x_{7}+31455x_{8}+323x_{9}+13170x_{10}} & \leqslant 346θ_{6} & (2)\\
# {3997x_{1}+2152x_{2}+1250x_{3}+645x_{4}+40807x_{5}+367x_{6}+6939x_{7}+25380x_{8}+58x_{9}+9363x_{10}} & \leqslant  367θ_{6} & (3)\\
# {531x_{1}+283x_{2}+75.5x_{3}+214x_{4}+2102x_{5}+32.9x_{6}+536x_{7}+900x_{8}+14.2x_{9}+476x_{10}} & \leqslant 32.9θ_{6} & (1)\\
# {9471x_{1}+5859x_{2}+1866x_{3}+3540x_{4}+17009x_{5}+529x_{6}+6761x_{7}+7756x_{8}+371x_{9}+8027x_{10}} & \geqslant 529 & (1)\\
# {2811x_{1}+1200x_{2}+3772x_{3}+1807x_{4}+3895x_{5}+274x_{6}+1162x_{7}+5644x_{8}+ 5x_{9}+952x_{10}} & \geqslant  274 & (1)\\
# θ_{6} & \leqslant 1
# \end{align}
# \right.
# $

# %%
𝑥6 = 0
# main constraints
prob += 626*𝑥1+466*𝑥2+98.7*𝑥3+242*𝑥4+1367*𝑥5+57.2*𝑥6+549*𝑥7+807*𝑥8+1.4*𝑥9+567*𝑥10 <=57.2*θ6

# %%
prob += 13292*𝑥1+8762*𝑥2+5881*𝑥3+5449*𝑥4+51182*𝑥5+346*𝑥6+10560*𝑥7+31455*𝑥8+323*𝑥9+13170*𝑥10 <=346*θ6

# %%
prob += 3997*𝑥1+2152*𝑥2+1250*𝑥3+6454*x4+40807*𝑥5+367*𝑥6+6939*𝑥7+25380*𝑥8+58*𝑥9+9363*𝑥10 <=367*θ6

# %%
prob += 531*𝑥1+283*𝑥2+75.5*𝑥3+214*𝑥4+2102*𝑥5+32.9*𝑥6+536*𝑥7+900*𝑥8+14.2*𝑥9+476*𝑥10 <=32.9*θ6

# %%
prob += 9471*𝑥1+5859*𝑥2+1866*𝑥3+3540*𝑥4+17009*𝑥5+529*𝑥6+6761*𝑥7+7756*𝑥8+371*𝑥9+8027*𝑥10 >=529

# %%
prob += 2811*𝑥1+1200*𝑥2+3772*𝑥3+1807*𝑥4+3895*𝑥5+274*𝑥6+1162*𝑥7+5644*𝑥8+5*𝑥9+952*𝑥10 >=274

# %%
print(prob)
# Out:
# DEA_B6:
# MINIMIZE
# 1*θ6 + 0
# SUBJECT TO
# _C1: 626 x1 + 567 x10 + 466 x2 + 98.7 x3 + 242 x4 + 1367 x5 + 549 x7 + 807 x8
#  + 1.4 x9 - 57.2 θ6 <= 0
#
# _C2: 13292 x1 + 13170 x10 + 8762 x2 + 5881 x3 + 5449 x4 + 51182 x5 + 10560 x7
#  + 31455 x8 + 323 x9 - 346 θ6 <= 0
#
# _C3: 3997 x1 + 9363 x10 + 2152 x2 + 1250 x3 + 6454 x4 + 40807 x5 + 6939 x7
#  + 25380 x8 + 58 x9 - 367 θ6 <= 0
#
# _C4: 531 x1 + 476 x10 + 283 x2 + 75.5 x3 + 214 x4 + 2102 x5 + 536 x7 + 900 x8
#  + 14.2 x9 - 32.9 θ6 <= 0
#
# _C5: 9471 x1 + 8027 x10 + 5859 x2 + 1866 x3 + 3540 x4 + 17009 x5 + 6761 x7
#  + 7756 x8 + 371 x9 >= 529
#
# _C6: 2811 x1 + 952 x10 + 1200 x2 + 3772 x3 + 1807 x4 + 3895 x5 + 1162 x7
#  + 5644 x8 + 5 x9 >= 274
#
# VARIABLES
# x1 Continuous
# x10 Continuous
# x2 Continuous
# x3 Continuous
# x4 Continuous
# x5 Continuous
# x7 Continuous
# x8 Continuous
# x9 Continuous
# θ6 <= 1 Continuous

# %%
print(prob)
# Out:
# DEA_B6:
# MINIMIZE
# 1*θ6 + 0
# SUBJECT TO
# _C1: 626 x1 + 567 x10 + 466 x2 + 98.7 x3 + 242 x4 + 1367 x5 + 549 x7 + 807 x8
#  + 1.4 x9 - 57.2 θ6 <= 0
#
# _C2: 13292 x1 + 13170 x10 + 8762 x2 + 5881 x3 + 5449 x4 + 51182 x5 + 10560 x7
#  + 31455 x8 + 323 x9 - 346 θ6 <= 0
#
# _C3: 3997 x1 + 9363 x10 + 2152 x2 + 1250 x3 + 6454 x4 + 40807 x5 + 6939 x7
#  + 25380 x8 + 58 x9 - 367 θ6 <= 0
#
# _C4: 531 x1 + 476 x10 + 283 x2 + 75.5 x3 + 214 x4 + 2102 x5 + 536 x7 + 900 x8
#  + 14.2 x9 - 32.9 θ6 <= 0
#
# _C5: 9471 x1 + 8027 x10 + 5859 x2 + 1866 x3 + 3540 x4 + 17009 x5 + 6761 x7
#  + 7756 x8 + 371 x9 >= 529
#
# _C6: 2811 x1 + 952 x10 + 1200 x2 + 3772 x3 + 1807 x4 + 3895 x5 + 1162 x7
#  + 5644 x8 + 5 x9 >= 274
#
# VARIABLES
# x1 Continuous
# x10 Continuous
# x2 Continuous
# x3 Continuous
# x4 Continuous
# x5 Continuous
# x7 Continuous
# x8 Continuous
# x9 Continuous
# θ6 <= 1 Continuous

# %% [markdown]
# ### Rozwiązanie problemu

# %%
print("prob.solve",prob.solve())
# status of the solution
print(f"Status: {LpStatus[prob.status]}")
# Out:
# prob.solve -1
# Status: Infeasible

# %%
for v in prob.variables():
    print(f"{v.name} = {str(Fraction(v.varValue).limit_denominator())}")
# Out:
# x1 = 0
# x10 = 0
# x2 = 0
# x3 = 38993/547460
# x4 = 0
# x5 = 0
# x7 = 0
# x8 = 0
# x9 = 119111/111565
# θ6 = 724261/328122

# %%
x3 = 38993/547460
x3
# Out:
# 0.07122529499872136

# %%
x9 = 119111/111565
x9
# Out:
# 1.0676376999955184

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style="font-size: 150%;color:white;background:red">Wydajność B6 (Bank Gospodarstwa Krajowego) wynosi 100%

# %%
B6 = 724261/328122
B6
# Out:
# 2.207291800001219

# %%
# maximum value of the objective function
print(f"max (x11+x12+x13+x21+x22+x23+x31+x32+x33+x41+x42+x43) = {str(Fraction(value(prob.objective)).limit_denominator())}")
# Out:
# max (x11+x12+x13+x21+x22+x23+x31+x32+x33+x41+x42+x43) = 724261/328122

# %% [markdown]
# <span style="font-size: 350%;color:white;background:#1155cc"> B7 </span>
# <span style="font-size: 350%;color:white;background:red">     Bank Śląski

# %%
from pulp import *
from fractions import Fraction

# zdefiniowanie problemu- to jest taka platforma do wrzucania na nia wszystkiego

prob = LpProblem("DEA_B7",LpMinimize)

# %%
# "Continuous"
# "Integer"

x1=LpVariable("x1",lowBound=0,upBound=None, cat="Continuous")
x2=LpVariable("x2",lowBound=0,upBound=None, cat="Continuous")
x3=LpVariable("x3",lowBound=0,upBound=None, cat="Continuous")
x4=LpVariable("x4",lowBound=0,upBound=None, cat="Continuous")
x5=LpVariable("x5",lowBound=0,upBound=None, cat="Continuous")
x6=LpVariable("x6",lowBound=0,upBound=None, cat="Continuous")
x7=LpVariable("x7",lowBound=0,upBound=None, cat="Continuous")
x8=LpVariable("x8",lowBound=0,upBound=None, cat="Continuous")
x9=LpVariable("x9",lowBound=0,upBound=None, cat="Continuous")
x10=LpVariable("x10",lowBound=0,upBound=None, cat="Continuous")
θ7=LpVariable("θ7",lowBound=0,upBound=1, cat="Continuous")

# %% [markdown]
# ### Dodajemy do platformy funkcje celu
#
# Funkcja celu - maksymalizacja
#
# # $
# θ_{7}  \to min\\
# $

# %%
# objective function
prob += θ7, "Minimalizacja"

# %%
print(prob)
# Out:
# DEA_B7:
# MINIMIZE
# 1*θ7 + 0
# VARIABLES
# θ7 <= 1 Continuous

# %%
from beautifultable import BeautifulTable

table = BeautifulTable()
table.column_headers = ["Bank","B1","B2","B3","B4","B5","B6","B7","B8","B9","B10"]
table.append_row(["Majątek",626,466 ,98.7,242,1367,57.2,549,807,1.4,567])
table.append_row(["Wkład",13292,8762 ,5881,5449,51182,346,10560,31455,323,13170 ])
table.append_row(["Zatrudnienie",3997,2152,1250,645,40807,367,6939,25380,58,9363 ])
table.append_row(["Koszty",531,283,75.5,214,2102,32.9,536,900,14.2,476])
table.append_row(["Kredyty",9471,5859,1866,3540,17009,529,6761,7756,371,8027])
table.append_row(["Należności",2811,1200,3772,1807,3895,274,1162,5644,5,952])
print(table)
# Out:
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |   Bank    |  B1   |  B2  |  B3  |  B4  | B5  |  B6  | B7  | B8  |  B9  | B10 |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |  Majątek  |  626  | 466  | 98.7 | 242  | 136 | 57.2 | 549 | 807 | 1.4  | 567 |
# |           |       |      |      |      |  7  |      |     |     |      |     |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |   Wkład   | 13292 | 8762 | 5881 | 5449 | 511 | 346  | 105 | 314 | 323  | 131 |
# |           |       |      |      |      | 82  |      | 60  | 55  |      | 70  |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# | Zatrudnie | 3997  | 2152 | 1250 | 645  | 408 | 367  | 693 | 253 |  58  | 936 |
# |    nie    |       |      |      |      | 07  |      |  9  | 80  |      |  3  |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# ...

# %% [markdown]
# #### $
# \left\{
# \begin{align}
# {626x_{1}+466x_{2}+98.7x_{3}+242x_{4}+1367x_{5}+57.2x_{6}+549x_{7}+807x_{8}+1.4x_{9}+567x_{10}} & \leqslant 549θ_{7} & (1)\\
# {13292x_{1}+8762x_{2}+5881x_{3}+5449x_{4}+51182x_{5}+346x_{6}+10560x_{7}+31455x_{8}+323x_{9}+13170x_{10}} & \leqslant 10560θ_{7} & (2)\\
# {3997x_{1}+2152x_{2}+1250x_{3}+645x_{4}+40807x_{5}+367x_{6}+6939x_{7}+25380x_{8}+58x_{9}+9363x_{10}} & \leqslant  6939θ_{7} & (3)\\
# {531x_{1}+283x_{2}+75.5x_{3}+214x_{4}+2102x_{5}+32.9x_{6}+536x_{7}+900x_{8}+14.2x_{9}+476x_{10}} & \leqslant 536θ_{7} & (1)\\
# {9471x_{1}+5859x_{2}+1866x_{3}+3540x_{4}+17009x_{5}+529x_{6}+6761x_{7}+7756x_{8}+371x_{9}+8027x_{10}} & \geqslant 6761 & (1)\\
# {2811x_{1}+1200x_{2}+3772x_{3}+1807x_{4}+3895x_{5}+274x_{6}+1162x_{7}+5644x_{8}+ 5x_{9}+952x_{10}} & \geqslant  1162 & (1)\\
# θ_{7} & \leqslant 1
# \end{align}
# \right.
# $

# %%
𝑥7 = 0

# main constraints
prob += 626*𝑥1+466*𝑥2+98.7*𝑥3+242*𝑥4+1367*𝑥5+57.2*𝑥6+549*𝑥7+807*𝑥8+1.4*𝑥9+567*𝑥10 <=549*θ7

# %%
prob += 13292*𝑥1+8762*𝑥2+5881*𝑥3+5449*𝑥4+51182*𝑥5+346*𝑥6+10560*𝑥7+31455*𝑥8+323*𝑥9+13170*𝑥10 <=10560*θ7

# %%
prob += 3997*𝑥1+2152*𝑥2+1250*𝑥3+6454*x4+40807*𝑥5+367*𝑥6+6939*𝑥7+25380*𝑥8+58*𝑥9+9363*𝑥10 <=6939*θ7

# %%
prob += 531*𝑥1+283*𝑥2+75.5*𝑥3+214*𝑥4+2102*𝑥5+32.9*𝑥6+536*𝑥7+900*𝑥8+14.2*𝑥9+476*𝑥10 <=536*θ7

# %%
prob += 9471*𝑥1+5859*𝑥2+1866*𝑥3+3540*𝑥4+17009*𝑥5+529*𝑥6+6761*𝑥7+7756*𝑥8+371*𝑥9+8027*𝑥10 >=6761

# %%
prob += 2811*𝑥1+1200*𝑥2+3772*𝑥3+1807*𝑥4+3895*𝑥5+274*𝑥6+1162*𝑥7+5644*𝑥8+5*𝑥9+952*𝑥10 >=1162

# %%
print(prob)
# Out:
# DEA_B7:
# MINIMIZE
# 1*θ7 + 0
# SUBJECT TO
# _C1: 626 x1 + 567 x10 + 466 x2 + 98.7 x3 + 242 x4 + 1367 x5 + 57.2 x6 + 807 x8
#  + 1.4 x9 - 549 θ7 <= 0
#
# _C2: 13292 x1 + 13170 x10 + 8762 x2 + 5881 x3 + 5449 x4 + 51182 x5 + 346 x6
#  + 31455 x8 + 323 x9 - 10560 θ7 <= 0
#
# _C3: 3997 x1 + 9363 x10 + 2152 x2 + 1250 x3 + 6454 x4 + 40807 x5 + 367 x6
#  + 25380 x8 + 58 x9 - 6939 θ7 <= 0
#
# _C4: 531 x1 + 476 x10 + 283 x2 + 75.5 x3 + 214 x4 + 2102 x5 + 32.9 x6 + 900 x8
#  + 14.2 x9 - 536 θ7 <= 0
#
# _C5: 9471 x1 + 8027 x10 + 5859 x2 + 1866 x3 + 3540 x4 + 17009 x5 + 529 x6
#  + 7756 x8 + 371 x9 >= 6761
#
# _C6: 2811 x1 + 952 x10 + 1200 x2 + 3772 x3 + 1807 x4 + 3895 x5 + 274 x6
#  + 5644 x8 + 5 x9 >= 1162
#
# VARIABLES
# x1 Continuous
# x10 Continuous
# x2 Continuous
# x3 Continuous
# x4 Continuous
# x5 Continuous
# x6 Continuous
# x8 Continuous
# x9 Continuous
# θ7 <= 1 Continuous

# %%
print(prob)
# Out:
# DEA_B7:
# MINIMIZE
# 1*θ7 + 0
# SUBJECT TO
# _C1: 626 x1 + 567 x10 + 466 x2 + 98.7 x3 + 242 x4 + 1367 x5 + 57.2 x6 + 807 x8
#  + 1.4 x9 - 549 θ7 <= 0
#
# _C2: 13292 x1 + 13170 x10 + 8762 x2 + 5881 x3 + 5449 x4 + 51182 x5 + 346 x6
#  + 31455 x8 + 323 x9 - 10560 θ7 <= 0
#
# _C3: 3997 x1 + 9363 x10 + 2152 x2 + 1250 x3 + 6454 x4 + 40807 x5 + 367 x6
#  + 25380 x8 + 58 x9 - 6939 θ7 <= 0
#
# _C4: 531 x1 + 476 x10 + 283 x2 + 75.5 x3 + 214 x4 + 2102 x5 + 32.9 x6 + 900 x8
#  + 14.2 x9 - 536 θ7 <= 0
#
# _C5: 9471 x1 + 8027 x10 + 5859 x2 + 1866 x3 + 3540 x4 + 17009 x5 + 529 x6
#  + 7756 x8 + 371 x9 >= 6761
#
# _C6: 2811 x1 + 952 x10 + 1200 x2 + 3772 x3 + 1807 x4 + 3895 x5 + 274 x6
#  + 5644 x8 + 5 x9 >= 1162
#
# VARIABLES
# x1 Continuous
# x10 Continuous
# x2 Continuous
# x3 Continuous
# x4 Continuous
# x5 Continuous
# x6 Continuous
# x8 Continuous
# x9 Continuous
# θ7 <= 1 Continuous

# %% [markdown]
# ### Rozwiązanie problemu

# %%
print("prob.solve",prob.solve())
# status of the solution
print(f"Status: {LpStatus[prob.status]}")
# Out:
# prob.solve 1
# Status: Optimal

# %%
for v in prob.variables():
    print(f"{v.name} = {str(Fraction(v.varValue).limit_denominator())}")
# Out:
# x1 = 0
# x10 = 0
# x2 = 0
# x3 = 49014/677179
# x4 = 0
# x5 = 0
# x6 = 2267704/756777
# x8 = 0
# x9 = 13586997/1000000
# θ7 = 469457/847276

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x3 = 49014/677179
x3
# Out:
# 0.07237968100014915

# %%
x6 = 2267704/756777
x6
# Out:
# 2.996528700000132

# %%
x9 = 13586997/1000000
x9
# Out:
# 13.586997

# %% [markdown]
# <span style="font-size: 150%;color:white;background:red">Wydajność B7 (Bank Śląski) wynosi 0.554

# %%
B7 =469457/847276
B7
# Out:
# 0.5540780099991031

# %%
# maximum value of the objective function
print(f"max (x11+x12+x13+x21+x22+x23+x31+x32+x33+x41+x42+x43) = {str(Fraction(value(prob.objective)).limit_denominator())}")
# Out:
# max (x11+x12+x13+x21+x22+x23+x31+x32+x33+x41+x42+x43) = 469457/847276

# %% [markdown]
# <span style="font-size: 350%;color:white;background:#1155cc"> B8 </span>
# <span style="font-size: 350%;color:white;background:red">      PeKaO S.A.

# %%
from pulp import *
from fractions import Fraction

# zdefiniowanie problemu- to jest taka platforma do wrzucania na nia wszystkiego

prob = LpProblem("DEA_B8",LpMinimize)

# %%
# "Continuous"
# "Integer"

x1=LpVariable("x1",lowBound=0,upBound=None, cat="Continuous")
x2=LpVariable("x2",lowBound=0,upBound=None, cat="Continuous")
x3=LpVariable("x3",lowBound=0,upBound=None, cat="Continuous")
x4=LpVariable("x4",lowBound=0,upBound=None, cat="Continuous")
x5=LpVariable("x5",lowBound=0,upBound=None, cat="Continuous")
x6=LpVariable("x6",lowBound=0,upBound=None, cat="Continuous")
x7=LpVariable("x7",lowBound=0,upBound=None, cat="Continuous")
x8=LpVariable("x8",lowBound=0,upBound=None, cat="Continuous")
x9=LpVariable("x9",lowBound=0,upBound=None, cat="Continuous")
x10=LpVariable("x10",lowBound=0,upBound=None, cat="Continuous")
θ8=LpVariable("θ8",lowBound=0,upBound=1, cat="Continuous")

# %% [markdown]
# ### Dodajemy do platformy funkcje celu
#
# Funkcja celu - maksymalizacja
#
# # $
# θ_{8}  \to min\\
# $

# %%
# objective function
prob += θ8, "Minimalizacja"

# %%
print(prob)
# Out:
# DEA_B8:
# MINIMIZE
# 1*θ8 + 0
# VARIABLES
# θ8 <= 1 Continuous

# %%
from beautifultable import BeautifulTable

table = BeautifulTable()
table.column_headers = ["Bank","B1","B2","B3","B4","B5","B6","B7","B8","B9","B10"]
table.append_row(["Majątek",626,466 ,98.7,242,1367,57.2,549,807,1.4,567])
table.append_row(["Wkład",13292,8762 ,5881,5449,51182,346,10560,31455,323,13170 ])
table.append_row(["Zatrudnienie",3997,2152,1250,645,40807,367,6939,25380,58,9363 ])
table.append_row(["Koszty",531,283,75.5,214,2102,32.9,536,900,14.2,476])
table.append_row(["Kredyty",9471,5859,1866,3540,17009,529,6761,7756,371,8027])
table.append_row(["Należności",2811,1200,3772,1807,3895,274,1162,5644,5,952])
print(table)
# Out:
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |   Bank    |  B1   |  B2  |  B3  |  B4  | B5  |  B6  | B7  | B8  |  B9  | B10 |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |  Majątek  |  626  | 466  | 98.7 | 242  | 136 | 57.2 | 549 | 807 | 1.4  | 567 |
# |           |       |      |      |      |  7  |      |     |     |      |     |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |   Wkład   | 13292 | 8762 | 5881 | 5449 | 511 | 346  | 105 | 314 | 323  | 131 |
# |           |       |      |      |      | 82  |      | 60  | 55  |      | 70  |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# | Zatrudnie | 3997  | 2152 | 1250 | 645  | 408 | 367  | 693 | 253 |  58  | 936 |
# |    nie    |       |      |      |      | 07  |      |  9  | 80  |      |  3  |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# ...

# %% [markdown]
# #### $
# \left\{
# \begin{align}
# {626x_{1}+466x_{2}+98.7x_{3}+242x_{4}+1367x_{5}+57.2x_{6}+549x_{7}+807x_{8}+1.4x_{9}+567x_{10}} & \leqslant 807θ_{8} & (1)\\
# {13292x_{1}+8762x_{2}+5881x_{3}+5449x_{4}+51182x_{5}+346x_{6}+10560x_{7}+31455x_{8}+323x_{9}+13170x_{10}} & \leqslant 31455θ_{8} & (2)\\
# {3997x_{1}+2152x_{2}+1250x_{3}+645x_{4}+40807x_{5}+367x_{6}+6939x_{7}+25380x_{8}+58x_{9}+9363x_{10}} & \leqslant  25380θ_{8} & (3)\\
# {531x_{1}+283x_{2}+75.5x_{3}+214x_{4}+2102x_{5}+32.9x_{6}+536x_{7}+900x_{8}+14.2x_{9}+476x_{10}} & \leqslant 900θ_{8} & (4)\\
# {9471x_{1}+5859x_{2}+1866x_{3}+3540x_{4}+17009x_{5}+529x_{6}+6761x_{7}+7756x_{8}+371x_{9}+8027x_{10}} & \geqslant 7756 & (5)\\
# {2811x_{1}+1200x_{2}+3772x_{3}+1807x_{4}+3895x_{5}+274x_{6}+1162x_{7}+5644x_{8}+ 5x_{9}+952x_{10}} & \geqslant  5644 & (6)\\
# θ_{8} & \leqslant 1
# \end{align}
# \right.
# $

# %%
𝑥8 = 0

# main constraints
prob += 626*𝑥1+466*𝑥2+98.7*𝑥3+242*𝑥4+1367*𝑥5+57.2*𝑥6+549*𝑥7+807*𝑥8+1.4*𝑥9+567*𝑥10 <=807*θ8

# %%
prob += 13292*𝑥1+8762*𝑥2+5881*𝑥3+5449*𝑥4+51182*𝑥5+346*𝑥6+10560*𝑥7+31455*𝑥8+323*𝑥9+13170*𝑥10 <=31455*θ8

# %%
prob += 3997*𝑥1+2152*𝑥2+1250*𝑥3+6454*x4+40807*𝑥5+367*𝑥6+6939*𝑥7+25380*𝑥8+58*𝑥9+9363*𝑥10 <=25380*θ8

# %%
prob += 531*𝑥1+283*𝑥2+75.5*𝑥3+214*𝑥4+2102*𝑥5+32.9*𝑥6+536*𝑥7+900*𝑥8+14.2*𝑥9+476*𝑥10 <=900*θ8

# %%
prob += 9471*𝑥1+5859*𝑥2+1866*𝑥3+3540*𝑥4+17009*𝑥5+529*𝑥6+6761*𝑥7+7756*𝑥8+371*𝑥9+8027*𝑥10 >=7756

# %%
prob += 2811*𝑥1+1200*𝑥2+3772*𝑥3+1807*𝑥4+3895*𝑥5+274*𝑥6+1162*𝑥7+5644*𝑥8+5*𝑥9+952*𝑥10 >=5644

# %%
print(prob)
# Out:
# DEA_B8:
# MINIMIZE
# 1*θ8 + 0
# SUBJECT TO
# _C1: 626 x1 + 567 x10 + 466 x2 + 98.7 x3 + 242 x4 + 1367 x5 + 57.2 x6 + 549 x7
#  + 1.4 x9 - 807 θ8 <= 0
#
# _C2: 13292 x1 + 13170 x10 + 8762 x2 + 5881 x3 + 5449 x4 + 51182 x5 + 346 x6
#  + 10560 x7 + 323 x9 - 31455 θ8 <= 0
#
# _C3: 3997 x1 + 9363 x10 + 2152 x2 + 1250 x3 + 6454 x4 + 40807 x5 + 367 x6
#  + 6939 x7 + 58 x9 - 25380 θ8 <= 0
#
# _C4: 531 x1 + 476 x10 + 283 x2 + 75.5 x3 + 214 x4 + 2102 x5 + 32.9 x6 + 536 x7
#  + 14.2 x9 - 900 θ8 <= 0
#
# _C5: 9471 x1 + 8027 x10 + 5859 x2 + 1866 x3 + 3540 x4 + 17009 x5 + 529 x6
#  + 6761 x7 + 371 x9 >= 7756
#
# _C6: 2811 x1 + 952 x10 + 1200 x2 + 3772 x3 + 1807 x4 + 3895 x5 + 274 x6
#  + 1162 x7 + 5 x9 >= 5644
#
# VARIABLES
# x1 Continuous
# x10 Continuous
# x2 Continuous
# x3 Continuous
# x4 Continuous
# x5 Continuous
# x6 Continuous
# x7 Continuous
# x9 Continuous
# θ8 <= 1 Continuous

# %%
print(prob)
# Out:
# DEA_B8:
# MINIMIZE
# 1*θ8 + 0
# SUBJECT TO
# _C1: 626 x1 + 567 x10 + 466 x2 + 98.7 x3 + 242 x4 + 1367 x5 + 57.2 x6 + 549 x7
#  + 1.4 x9 - 807 θ8 <= 0
#
# _C2: 13292 x1 + 13170 x10 + 8762 x2 + 5881 x3 + 5449 x4 + 51182 x5 + 346 x6
#  + 10560 x7 + 323 x9 - 31455 θ8 <= 0
#
# _C3: 3997 x1 + 9363 x10 + 2152 x2 + 1250 x3 + 6454 x4 + 40807 x5 + 367 x6
#  + 6939 x7 + 58 x9 - 25380 θ8 <= 0
#
# _C4: 531 x1 + 476 x10 + 283 x2 + 75.5 x3 + 214 x4 + 2102 x5 + 32.9 x6 + 536 x7
#  + 14.2 x9 - 900 θ8 <= 0
#
# _C5: 9471 x1 + 8027 x10 + 5859 x2 + 1866 x3 + 3540 x4 + 17009 x5 + 529 x6
#  + 6761 x7 + 371 x9 >= 7756
#
# _C6: 2811 x1 + 952 x10 + 1200 x2 + 3772 x3 + 1807 x4 + 3895 x5 + 274 x6
#  + 1162 x7 + 5 x9 >= 5644
#
# VARIABLES
# x1 Continuous
# x10 Continuous
# x2 Continuous
# x3 Continuous
# x4 Continuous
# x5 Continuous
# x6 Continuous
# x7 Continuous
# x9 Continuous
# θ8 <= 1 Continuous

# %% [markdown]
# ### Rozwiązanie problemu

# %%
print("prob.solve",prob.solve())
# status of the solution
print(f"Status: {LpStatus[prob.status]}")
# Out:
# prob.solve 1
# Status: Optimal

# %%
for v in prob.variables():
    print(f"{v.name} = {str(Fraction(v.varValue).limit_denominator())}")
# Out:
# x1 = 0
# x10 = 0
# x2 = 0
# x3 = 1147342/900107
# x4 = 0
# x5 = 0
# x6 = 2817619/984909
# x7 = 0
# x9 = 10415369/1000000
# θ8 = 317835/843646

# %% [markdown]
# <span style="font-size: 150%;color:white;background:red">Wydajność B8 (PeKaO S.A.) wynosi 0.377

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x3 = 1147342/900107
x4 = 0
x5 = 0
x6 = 2817619/984909
x7 = 0
x9 = 10415369/1000000

# %%
x3
# Out:
# 1.2746728999996666

# %%
x6
# Out:
# 2.8607911999991877

# %%
x9
# Out:
# 10.415369

# %%
B8= 317835/843646
B8
# Out:
# 0.3767397699983168

# %%
# maximum value of the objective function
print(f"max (x11+x12+x13+x21+x22+x23+x31+x32+x33+x41+x42+x43) = {str(Fraction(value(prob.objective)).limit_denominator())}")
# Out:
# max (x11+x12+x13+x21+x22+x23+x31+x32+x33+x41+x42+x43) = 317835/843646

# %% [markdown]
# <span style="font-size: 350%;color:white;background:#1155cc"> B9 </span>
# <span style="font-size: 350%;color:white;background:red">     Opel Bank

# %%
from beautifultable import BeautifulTable

table = BeautifulTable()
table.column_headers = ["Bank","B1","B2","B3","B4","B5","B6","B7","B8","B9","B10"]
table.append_row(["Majątek",626,466 ,98.7,242,1367,57.2,549,807,1.4,567])
table.append_row(["Wkład",13292,8762 ,5881,5449,51182,346,10560,31455,323,13170 ])
table.append_row(["Zatrudnienie",3997,2152,1250,645,40807,367,6939,25380,58,9363 ])
table.append_row(["Koszty",531,283,75.5,214,2102,32.9,536,900,14.2,476])
table.append_row(["Kredyty",9471,5859,1866,3540,17009,529,6761,7756,371,8027])
table.append_row(["Należności",2811,1200,3772,1807,3895,274,1162,5644,5,952])
print(table)
# Out:
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |   Bank    |  B1   |  B2  |  B3  |  B4  | B5  |  B6  | B7  | B8  |  B9  | B10 |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |  Majątek  |  626  | 466  | 98.7 | 242  | 136 | 57.2 | 549 | 807 | 1.4  | 567 |
# |           |       |      |      |      |  7  |      |     |     |      |     |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |   Wkład   | 13292 | 8762 | 5881 | 5449 | 511 | 346  | 105 | 314 | 323  | 131 |
# |           |       |      |      |      | 82  |      | 60  | 55  |      | 70  |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# | Zatrudnie | 3997  | 2152 | 1250 | 645  | 408 | 367  | 693 | 253 |  58  | 936 |
# |    nie    |       |      |      |      | 07  |      |  9  | 80  |      |  3  |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# ...

# %% [markdown]
# #### $
# \left\{
# \begin{align}
# {626x_{1}+466x_{2}+98.7x_{3}+242x_{4}+1367x_{5}+57.2x_{6}+549x_{7}+807x_{8}+1.4x_{9}+567x_{10}} & \leqslant 1.4θ_{9} & (1)\\
# {13292x_{1}+8762x_{2}+5881x_{3}+5449x_{4}+51182x_{5}+346x_{6}+10560x_{7}+31455x_{8}+323x_{9}+13170x_{10}} & \leqslant 323θ_{9} & (2)\\
# {3997x_{1}+2152x_{2}+1250x_{3}+645x_{4}+40807x_{5}+367x_{6}+6939x_{7}+25380x_{8}+58x_{9}+9363x_{10}} & \leqslant 58θ_{9} & (3)\\
# {531x_{1}+283x_{2}+75.5x_{3}+214x_{4}+2102x_{5}+32.9x_{6}+536x_{7}+900x_{8}+14.2x_{9}+476x_{10}} & \leqslant 14.2θ_{9} & (4)\\
# {9471x_{1}+5859x_{2}+1866x_{3}+3540x_{4}+17009x_{5}+529x_{6}+6761x_{7}+7756x_{8}+371x_{9}+8027x_{10}} & \geqslant 371 & (5)\\
# {2811x_{1}+1200x_{2}+3772x_{3}+1807x_{4}+3895x_{5}+274x_{6}+1162x_{7}+5644x_{8}+ 5x_{9}+952x_{10}} & \geqslant 5 & (6)\\
# θ_{9} & \leqslant 1
# \end{align}
# \right.
# $

# %%
from pulp import *
from fractions import Fraction

# zdefiniowanie problemu- to jest taka platforma do wrzucania na nia wszystkiego

prob = LpProblem("DEA_B10",LpMinimize)

# %%
# "Continuous"
# "Integer"

x1=LpVariable("x1",lowBound=0,upBound=None, cat="Continuous")
x2=LpVariable("x2",lowBound=0,upBound=None, cat="Continuous")
x3=LpVariable("x3",lowBound=0,upBound=None, cat="Continuous")
x4=LpVariable("x4",lowBound=0,upBound=None, cat="Continuous")
x5=LpVariable("x5",lowBound=0,upBound=None, cat="Continuous")
x6=LpVariable("x6",lowBound=0,upBound=None, cat="Continuous")
x7=LpVariable("x7",lowBound=0,upBound=None, cat="Continuous")
x8=LpVariable("x8",lowBound=0,upBound=None, cat="Continuous")
x9=LpVariable("x9",lowBound=0,upBound=None, cat="Continuous")
x10=LpVariable("x10",lowBound=0,upBound=None, cat="Continuous")
θ9=LpVariable("θ9",lowBound=0,upBound=1, cat="Continuous")

# %% [markdown]
# ### Dodajemy do platformy funkcje celu
#
# Funkcja celu - maksymalizacja Dorking
#
# # $
# θ_{9}  \to min\\
# $

# %%
# objective function
prob += θ9, "Minimalizacja"

# %%
print(prob)
# Out:
# DEA_B10:
# MINIMIZE
# 1*θ9 + 0
# VARIABLES
# θ9 <= 1 Continuous

# %% [markdown]
# #### $
# \left\{
# \begin{align}
# {626x_{1}+466x_{2}+98.7x_{3}+242x_{4}+1367x_{5}+57.2x_{6}+549x_{7}+807x_{8}+1.4x_{9}+567x_{10}} & \leqslant 1.4θ_{9} & (1)\\
# {13292x_{1}+8762x_{2}+5881x_{3}+5449x_{4}+51182x_{5}+346x_{6}+10560x_{7}+31455x_{8}+323x_{9}+13170x_{10}} & \leqslant 323θ_{9} & (2)\\
# {3997x_{1}+2152x_{2}+1250x_{3}+645x_{4}+40807x_{5}+367x_{6}+6939x_{7}+25380x_{8}+58x_{9}+9363x_{10}} & \leqslant 58θ_{9} & (3)\\
# {531x_{1}+283x_{2}+75.5x_{3}+214x_{4}+2102x_{5}+32.9x_{6}+536x_{7}+900x_{8}+14.2x_{9}+476x_{10}} & \leqslant 14.2θ_{9} & (4)\\
# {9471x_{1}+5859x_{2}+1866x_{3}+3540x_{4}+17009x_{5}+529x_{6}+6761x_{7}+7756x_{8}+371x_{9}+8027x_{10}} & \geqslant 371 & (5)\\
# {2811x_{1}+1200x_{2}+3772x_{3}+1807x_{4}+3895x_{5}+274x_{6}+1162x_{7}+5644x_{8}+ 5x_{9}+952x_{10}} & \geqslant 5 & (6)\\
# θ_{9} & \leqslant 1
# \end{align}
# \right.
# $

# %%
𝑥9 = 0

# main constraints
prob += 626*𝑥1+466*𝑥2+98.7*𝑥3+242*𝑥4+1367*𝑥5+57.2*𝑥6+549*𝑥7+807*𝑥8+1.4*𝑥9+567*𝑥10 <=1.4*θ9

# %%
prob += 13292*𝑥1+8762*𝑥2+5881*𝑥3+5449*𝑥4+51182*𝑥5+346*𝑥6+10560*𝑥7+31455*𝑥8+323*𝑥9+13170*𝑥10 <=323*θ9

# %%
prob += 3997*𝑥1+2152*𝑥2+1250*𝑥3+6454*x4+40807*𝑥5+367*𝑥6+6939*𝑥7+25380*𝑥8+58*𝑥9+9363*𝑥10 <=58*θ9

# %%
prob += 531*𝑥1+283*𝑥2+75.5*𝑥3+214*𝑥4+2102*𝑥5+32.9*𝑥6+536*𝑥7+900*𝑥8+14.2*𝑥9+476*𝑥10 <=14.2*θ9

# %%
prob += 9471*𝑥1+5859*𝑥2+1866*𝑥3+3540*𝑥4+17009*𝑥5+529*𝑥6+6761*𝑥7+7756*𝑥8+371*𝑥9+8027*𝑥10 >=371

# %%
prob += 2811*𝑥1+1200*𝑥2+3772*𝑥3+1807*𝑥4+3895*𝑥5+274*𝑥6+1162*𝑥7+5644*𝑥8+5*𝑥9+952*𝑥10 >=5

# %%
print(prob)
# Out:
# DEA_B10:
# MINIMIZE
# 1*θ9 + 0
# SUBJECT TO
# _C1: 626 x1 + 567 x10 + 466 x2 + 98.7 x3 + 242 x4 + 1367 x5 + 57.2 x6 + 549 x7
#  + 807 x8 - 1.4 θ9 <= 0
#
# _C2: 13292 x1 + 13170 x10 + 8762 x2 + 5881 x3 + 5449 x4 + 51182 x5 + 346 x6
#  + 10560 x7 + 31455 x8 - 323 θ9 <= 0
#
# _C3: 3997 x1 + 9363 x10 + 2152 x2 + 1250 x3 + 6454 x4 + 40807 x5 + 367 x6
#  + 6939 x7 + 25380 x8 - 58 θ9 <= 0
#
# _C4: 531 x1 + 476 x10 + 283 x2 + 75.5 x3 + 214 x4 + 2102 x5 + 32.9 x6 + 536 x7
#  + 900 x8 - 14.2 θ9 <= 0
#
# _C5: 9471 x1 + 8027 x10 + 5859 x2 + 1866 x3 + 3540 x4 + 17009 x5 + 529 x6
#  + 6761 x7 + 7756 x8 >= 371
#
# _C6: 2811 x1 + 952 x10 + 1200 x2 + 3772 x3 + 1807 x4 + 3895 x5 + 274 x6
#  + 1162 x7 + 5644 x8 >= 5
#
# VARIABLES
# x1 Continuous
# x10 Continuous
# x2 Continuous
# x3 Continuous
# x4 Continuous
# x5 Continuous
# x6 Continuous
# x7 Continuous
# x8 Continuous
# θ9 <= 1 Continuous

# %%
print(prob)
# Out:
# DEA_B10:
# MINIMIZE
# 1*θ9 + 0
# SUBJECT TO
# _C1: 626 x1 + 567 x10 + 466 x2 + 98.7 x3 + 242 x4 + 1367 x5 + 57.2 x6 + 549 x7
#  + 807 x8 - 1.4 θ9 <= 0
#
# _C2: 13292 x1 + 13170 x10 + 8762 x2 + 5881 x3 + 5449 x4 + 51182 x5 + 346 x6
#  + 10560 x7 + 31455 x8 - 323 θ9 <= 0
#
# _C3: 3997 x1 + 9363 x10 + 2152 x2 + 1250 x3 + 6454 x4 + 40807 x5 + 367 x6
#  + 6939 x7 + 25380 x8 - 58 θ9 <= 0
#
# _C4: 531 x1 + 476 x10 + 283 x2 + 75.5 x3 + 214 x4 + 2102 x5 + 32.9 x6 + 536 x7
#  + 900 x8 - 14.2 θ9 <= 0
#
# _C5: 9471 x1 + 8027 x10 + 5859 x2 + 1866 x3 + 3540 x4 + 17009 x5 + 529 x6
#  + 6761 x7 + 7756 x8 >= 371
#
# _C6: 2811 x1 + 952 x10 + 1200 x2 + 3772 x3 + 1807 x4 + 3895 x5 + 274 x6
#  + 1162 x7 + 5644 x8 >= 5
#
# VARIABLES
# x1 Continuous
# x10 Continuous
# x2 Continuous
# x3 Continuous
# x4 Continuous
# x5 Continuous
# x6 Continuous
# x7 Continuous
# x8 Continuous
# θ9 <= 1 Continuous

# %% [markdown]
# ### Rozwiązanie problemu

# %%
print("prob.solve",prob.solve())
# status of the solution
print(f"Status: {LpStatus[prob.status]}")
# Out:
# prob.solve -1
# Status: Infeasible

# %%
for v in prob.variables():
    print(f"{v.name} = {str(Fraction(v.varValue).limit_denominator())}")
# Out:
# x1 = 0
# x10 = 0
# x2 = 0
# x3 = 128029/643941
# x4 = 0
# x5 = 0
# x6 = 0
# x7 = 0
# x8 = 0
# θ9 = 14016881/1000000

# %%
# maximum value of the objective function
print(f"max (x11+x12+x13+x21+x22+x23+x31+x32+x33+x41+x42+x43) = {str(Fraction(value(prob.objective)).limit_denominator())}")
# Out:
# max (x11+x12+x13+x21+x22+x23+x31+x32+x33+x41+x42+x43) = 14016881/1000000

# %% [markdown]
# <span style="font-size: 150%;color:white;background:red"> Wydajność B9  (Opel Bank) wynosi 100%

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x3 = 128029/643941
x3
# Out:
# 0.1988210099993633

# %%
B9 = 14016881/1000000
B9
# Out:
# 14.016881

# %% [markdown]
# <span style="font-size: 350%;color:white;background:#1155cc"> B10

# %%
from beautifultable import BeautifulTable

table = BeautifulTable()
table.column_headers = ["Bank","B1","B2","B3","B4","B5","B6","B7","B8","B9","B10"]
table.append_row(["Majątek",626,466 ,98.7,242,1367,57.2,549,807,1.4,567])
table.append_row(["Wkład",13292,8762 ,5881,5449,51182,346,10560,31455,323,13170 ])
table.append_row(["Zatrudnienie",3997,2152,1250,645,40807,367,6939,25380,58,9363 ])
table.append_row(["Koszty",531,283,75.5,214,2102,32.9,536,900,14.2,476])
table.append_row(["Kredyty",9471,5859,1866,3540,17009,529,6761,7756,371,8027])
table.append_row(["Należności",2811,1200,3772,1807,3895,274,1162,5644,5,952])
print(table)
# Out:
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |   Bank    |  B1   |  B2  |  B3  |  B4  | B5  |  B6  | B7  | B8  |  B9  | B10 |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |  Majątek  |  626  | 466  | 98.7 | 242  | 136 | 57.2 | 549 | 807 | 1.4  | 567 |
# |           |       |      |      |      |  7  |      |     |     |      |     |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# |   Wkład   | 13292 | 8762 | 5881 | 5449 | 511 | 346  | 105 | 314 | 323  | 131 |
# |           |       |      |      |      | 82  |      | 60  | 55  |      | 70  |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# | Zatrudnie | 3997  | 2152 | 1250 | 645  | 408 | 367  | 693 | 253 |  58  | 936 |
# |    nie    |       |      |      |      | 07  |      |  9  | 80  |      |  3  |
# +-----------+-------+------+------+------+-----+------+-----+-----+------+-----+
# ...

# %%
from pulp import *
from fractions import Fraction

# zdefiniowanie problemu- to jest taka platforma do wrzucania na nia wszystkiego

prob = LpProblem("DEA_B10",LpMinimize)

# %%
# "Continuous"
# "Integer"

x1=LpVariable("x1",lowBound=0,upBound=None, cat="Continuous")
x2=LpVariable("x2",lowBound=0,upBound=None, cat="Continuous")
x3=LpVariable("x3",lowBound=0,upBound=None, cat="Continuous")
x4=LpVariable("x4",lowBound=0,upBound=None, cat="Continuous")
x5=LpVariable("x5",lowBound=0,upBound=None, cat="Continuous")
x6=LpVariable("x6",lowBound=0,upBound=None, cat="Continuous")
x7=LpVariable("x7",lowBound=0,upBound=None, cat="Continuous")
x8=LpVariable("x8",lowBound=0,upBound=None, cat="Continuous")
x9=LpVariable("x9",lowBound=0,upBound=None, cat="Continuous")
x10=LpVariable("x10",lowBound=0,upBound=None, cat="Continuous")
θ10=LpVariable("θ10",lowBound=0,upBound=1, cat="Continuous")

# %% [markdown]
# ### Dodajemy do platformy funkcje celu
#
# Funkcja celu - maksymalizacja Dorking
#
# # $
# θ_{10}  \to min\\
# $

# %%
# objective function
prob += θ10, "Minimalizacja"

# %%
print(prob)
# Out:
# DEA_B10:
# MINIMIZE
# 1*θ10 + 0
# VARIABLES
# θ10 <= 1 Continuous

# %% [markdown]
# #### $
# \left\{
# \begin{align}
# {626x_{1}+466x_{2}+98.7x_{3}+242x_{4}+1367x_{5}+57.2x_{6}+549x_{7}+807x_{8}+1.4x_{9}+567x_{10}} & \leqslant 567θ_{10} & (1)\\
# {13292x_{1}+8762x_{2}+5881x_{3}+5449x_{4}+51182x_{5}+346x_{6}+10560x_{7}+31455x_{8}+323x_{9}+13170x_{10}} & \leqslant 13170θ_{10} & (2)\\
# {3997x_{1}+2152x_{2}+1250x_{3}+645x_{4}+40807x_{5}+367x_{6}+6939x_{7}+25380x_{8}+58x_{9}+9363x_{10}} & \leqslant 9363θ_{10} & (3)\\
# {531x_{1}+283x_{2}+75.5x_{3}+214x_{4}+2102x_{5}+32.9x_{6}+536x_{7}+900x_{8}+14.2x_{9}+476x_{10}} & \leqslant 476θ_{10} & (4)\\
# {9471x_{1}+5859x_{2}+1866x_{3}+3540x_{4}+17009x_{5}+529x_{6}+6761x_{7}+7756x_{8}+371x_{9}+8027x_{10}} & \geqslant 8027 & (5)\\
# {2811x_{1}+1200x_{2}+3772x_{3}+1807x_{4}+3895x_{5}+274x_{6}+1162x_{7}+5644x_{8}+ 5x_{9}+952x_{10}} & \geqslant 952 & (6)\\
# θ_{10} & \leqslant 1
# \end{align}
# \right.
# $

# %%
𝑥10 =0

# main constraints
prob += 626*𝑥1+466*𝑥2+98.7*𝑥3+242*𝑥4+1367*𝑥5+57.2*𝑥6+549*𝑥7+807*𝑥8+1.4*𝑥9+567*𝑥10 <=567*θ10

# %%
prob += 13292*𝑥1+8762*𝑥2+5881*𝑥3+5449*𝑥4+51182*𝑥5+346*𝑥6+10560*𝑥7+31455*𝑥8+323*𝑥9+13170*𝑥10 <=13170*θ10

# %%
prob += 3997*𝑥1+2152*𝑥2+1250*𝑥3+6454*x4+40807*𝑥5+367*𝑥6+6939*𝑥7+25380*𝑥8+58*𝑥9+9363*𝑥10 <=9363*θ10

# %%
prob += 531*𝑥1+283*𝑥2+75.5*𝑥3+214*𝑥4+2102*𝑥5+32.9*𝑥6+536*𝑥7+900*𝑥8+14.2*𝑥9+476*𝑥10 <=476*θ10

# %%
prob += 9471*𝑥1+5859*𝑥2+1866*𝑥3+3540*𝑥4+17009*𝑥5+529*𝑥6+6761*𝑥7+7756*𝑥8+371*𝑥9+8027*𝑥10 >=8027

# %%
prob += 2811*𝑥1+1200*𝑥2+3772*𝑥3+1807*𝑥4+3895*𝑥5+274*𝑥6+1162*𝑥7+5644*𝑥8+5*𝑥9+952*𝑥10 >=952

# %%
print(prob)
# Out:
# DEA_B10:
# MINIMIZE
# 1*θ10 + 0
# SUBJECT TO
# _C1: 626 x1 + 466 x2 + 98.7 x3 + 242 x4 + 1367 x5 + 57.2 x6 + 549 x7 + 807 x8
#  + 1.4 x9 - 567 θ10 <= 0
#
# _C2: 13292 x1 + 8762 x2 + 5881 x3 + 5449 x4 + 51182 x5 + 346 x6 + 10560 x7
#  + 31455 x8 + 323 x9 - 13170 θ10 <= 0
#
# _C3: 3997 x1 + 2152 x2 + 1250 x3 + 6454 x4 + 40807 x5 + 367 x6 + 6939 x7
#  + 25380 x8 + 58 x9 - 9363 θ10 <= 0
#
# _C4: 531 x1 + 283 x2 + 75.5 x3 + 214 x4 + 2102 x5 + 32.9 x6 + 536 x7 + 900 x8
#  + 14.2 x9 - 476 θ10 <= 0
#
# _C5: 9471 x1 + 5859 x2 + 1866 x3 + 3540 x4 + 17009 x5 + 529 x6 + 6761 x7
#  + 7756 x8 + 371 x9 >= 8027
#
# _C6: 2811 x1 + 1200 x2 + 3772 x3 + 1807 x4 + 3895 x5 + 274 x6 + 1162 x7
#  + 5644 x8 + 5 x9 >= 952
#
# VARIABLES
# x1 Continuous
# x2 Continuous
# x3 Continuous
# x4 Continuous
# x5 Continuous
# x6 Continuous
# x7 Continuous
# x8 Continuous
# x9 Continuous
# θ10 <= 1 Continuous

# %%
print(prob)
# Out:
# DEA_B10:
# MINIMIZE
# 1*θ10 + 0
# SUBJECT TO
# _C1: 626 x1 + 466 x2 + 98.7 x3 + 242 x4 + 1367 x5 + 57.2 x6 + 549 x7 + 807 x8
#  + 1.4 x9 - 567 θ10 <= 0
#
# _C2: 13292 x1 + 8762 x2 + 5881 x3 + 5449 x4 + 51182 x5 + 346 x6 + 10560 x7
#  + 31455 x8 + 323 x9 - 13170 θ10 <= 0
#
# _C3: 3997 x1 + 2152 x2 + 1250 x3 + 6454 x4 + 40807 x5 + 367 x6 + 6939 x7
#  + 25380 x8 + 58 x9 - 9363 θ10 <= 0
#
# _C4: 531 x1 + 283 x2 + 75.5 x3 + 214 x4 + 2102 x5 + 32.9 x6 + 536 x7 + 900 x8
#  + 14.2 x9 - 476 θ10 <= 0
#
# _C5: 9471 x1 + 5859 x2 + 1866 x3 + 3540 x4 + 17009 x5 + 529 x6 + 6761 x7
#  + 7756 x8 + 371 x9 >= 8027
#
# _C6: 2811 x1 + 1200 x2 + 3772 x3 + 1807 x4 + 3895 x5 + 274 x6 + 1162 x7
#  + 5644 x8 + 5 x9 >= 952
#
# VARIABLES
# x1 Continuous
# x2 Continuous
# x3 Continuous
# x4 Continuous
# x5 Continuous
# x6 Continuous
# x7 Continuous
# x8 Continuous
# x9 Continuous
# θ10 <= 1 Continuous

# %% [markdown]
# ### Rozwiązanie problemu

# %%
print("prob.solve",prob.solve())
# status of the solution
print(f"Status: {LpStatus[prob.status]}")
# Out:
# prob.solve 1
# Status: Optimal

# %%
for v in prob.variables():
    print(f"{v.name} = {str(Fraction(v.varValue).limit_denominator())}")
# Out:
# x1 = 0
# x2 = 0
# x3 = 207084/919525
# x4 = 0
# x5 = 0
# x6 = 0
# x7 = 0
# x8 = 0
# x9 = 20503403/1000000
# θ10 = 248508/383869

# %%
# maximum value of the objective function
print(f"max (x11+x12+x13+x21+x22+x23+x31+x32+x33+x41+x42+x43) = {str(Fraction(value(prob.objective)).limit_denominator())}")
# Out:
# max (x11+x12+x13+x21+x22+x23+x31+x32+x33+x41+x42+x43) = 248508/383869

# %%
B10 = 248508/383869
B10
# Out:
# 0.6473771000002605

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x3 = 207084/919525
x4 = 0
x5 = 0
x6 = 0
x7 = 0
x8 = 0
x9 = 20503403/1000000

# %%
x3
# Out:
# 0.22520758000054375

# %%
x9
# Out:
# 20.503403

# %% [markdown]
# <span style="font-size: 150%;color:white;background:red"> Wydajność B10  (Bank Gospodarki Żywnościowej) wynosi 0.647

# %% [markdown]
# Wydajność banków

# %%
from beautifultable import BeautifulTable

table = BeautifulTable()
table.column_headers = ["Bank","Ocena"]
table.append_row(["B1",B1])
table.append_row(["B2",B2])
table.append_row(["B3",B3])
table.append_row(["B4",B4])
table.append_row(["B5",B5])
table.append_row(["B6",B6])
table.append_row(["B7",B7])
table.append_row(["B8",B8])
table.append_row(["B9",B9])
table.append_row(["B10",B10])
print(table)
# Out:
# +------+--------+
# | Bank | Ocena  |
# +------+--------+
# |  B1  | 0.757  |
# +------+--------+
# |  B2  | 0.797  |
# +------+--------+
# |  B3  | 6.805  |
# +------+--------+
# |  B4  | 1.556  |
# +------+--------+
# |  B5  | 0.336  |
# +------+--------+
# |  B6  | 2.207  |
# +------+--------+
# |  B7  | 0.554  |
# +------+--------+
# |  B8  | 0.377  |
# +------+--------+
# |  B9  | 14.017 |
# +------+--------+
# | B10  | 0.647  |
# +------+--------+
