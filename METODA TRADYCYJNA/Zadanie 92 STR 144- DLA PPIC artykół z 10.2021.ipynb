# %% [markdown]
# # Zadanie 92 STR 144- DLA PPIC artykół z 10.2021

# %%
p11 ="19.0 tys. zł"
p12 ="6.6 tys. zł"
p13 ="2.3 tys. zł"
p14 ="9.2 tys. zł"
p15 ="5.0 tys. zł" 

p21 ="17.3 tys. zł"
p22 ="7.2 tys. zł"
p23 ="2.1 tys. zł"
p24 ="8.9 tys. zł"
p25 ="5.1 tys. zł" 

p31 ="18.5 tys. zł"
p32 ="7.6 tys. zł"
p33 ="2.2 tys. zł"
p34 ="8.5 tys. zł"
p35 ="5.7 tys. zł" 

p31 ="18.3 tys. zł"
p32 ="7.8 tys. zł"
p33 ="2.8 tys. zł"
p34 ="8.5 tys. zł"
p35 ="5.7 tys. zł" 

p41 ="18.1 tys. zł"
p42 ="7.4 tys. zł"
p43 ="2.4 tys. zł"
p44 ="8.1 tys. zł"
p45 ="4.8 tys. zł" 

p51 ="18.6 tys. zł"
p52 ="8.6 tys. zł"
p53 ="2.6 tys. zł"
p54 ="8.9 tys. zł"
p55 ="5.9 tys. zł" 

p61 ="18.0 tys. zł"
p62 ="8.2 tys. zł"
p63 ="3.1 tys. zł"
p64 ="7.9 tys. zł"
p65 ="5.6 tys. zł" 

p71 ="19.3 tys. zł"
p72 ="8.2 tys. zł"
p73 ="3.5 tys. zł"
p74 ="9.4 tys. zł"
p75 ="5.7 tys. zł"

# %%
from prettytable import PrettyTable
t = PrettyTable(["Oferty :", "Piec","Wymiennik","Miesiarka plan.","Mikser spir.","Krajalnica"])

#t.align["Sulejówek PKP"] = "i"
#t.padding_width = 1
t.add_row(['Piekarnia Szamoty',p11,  p12,  p13,  p14, p15])
t.add_row(['Piekarnia Morsk',p21,  p22,  p23,  p24, p25])
t.add_row(['Pracownik 1',p31,  p32,  p33,  p34, p35])
t.add_row(['Pracownik 2',p41,  p42,  p43,  p44, p45])
t.add_row(['Piekarnia Krystyna',p51,  p52,  p53,  p54, p55])
t.add_row(['Szkoła piekarnicza',p61,  p62,  p63,  p64, p65])
t.add_row(['Piekarnia Falenty',p71,  p72,  p73,  p74, p75])
print(t)
# Out:
# +--------------------+--------------+-------------+-----------------+--------------+-------------+
# |      Oferty :      |     Piec     |  Wymiennik  | Miesiarka plan. | Mikser spir. |  Krajalnica |
# +--------------------+--------------+-------------+-----------------+--------------+-------------+
# | Piekarnia Szamoty  | 19.0 tys. zł | 6.6 tys. zł |   2.3 tys. zł   | 9.2 tys. zł  | 5.0 tys. zł |
# |  Piekarnia Morsk   | 17.3 tys. zł | 7.2 tys. zł |   2.1 tys. zł   | 8.9 tys. zł  | 5.1 tys. zł |
# |    Pracownik 1     | 18.3 tys. zł | 7.8 tys. zł |   2.8 tys. zł   | 8.5 tys. zł  | 5.7 tys. zł |
# |    Pracownik 2     | 18.1 tys. zł | 7.4 tys. zł |   2.4 tys. zł   | 8.1 tys. zł  | 4.8 tys. zł |
# | Piekarnia Krystyna | 18.6 tys. zł | 8.6 tys. zł |   2.6 tys. zł   | 8.9 tys. zł  | 5.9 tys. zł |
# | Szkoła piekarnicza | 18.0 tys. zł | 8.2 tys. zł |   3.1 tys. zł   | 7.9 tys. zł  | 5.6 tys. zł |
# ...

# %% [markdown]
# <span style="font-size: 150%;color:#0000ff">Krok 1: ZMIENNA DECYZYJNA Czym jest x? </span>
#
# zero-jeden   - dlaczego? bo jest to zmienna decyzyjna, to jest przydział. jeden - ktoś kupuje, zero ktoś nie kupuje. Pronlrm jest, że czterech gości chce kupić samochody a samochodów jest 3 więc powinnismy utworzyc jeden samochód fantomowy (sztuczny). Jego wybór bedzie ioznaczał że ktoś nie kupił samochodu.
#
#
# <span style="font-size: 150%;color:#0000ff"> Krok 2: Co jest w tabeli?</span>
#
# ceny samochodów
#
# <span style="font-size: 150%;color:#0000ff"> Krok 3: ograniczenie zmiennych decyzyjnych</span>
#
#
# zmiennymi decyzyjnymi jest tutaj przydział, liczba 1 lub 0. Każdy pracownik ma kupić maksymalnie 1 samochód!
# Pracownik nie może kupić ujemną liczbę samochodów.
#
# TWORZONY JEST JEDEN WIĘCEJ SAMOCHÓD FANTOMOWY
#
# #### $
# \left\{
# \begin{align}
# {x_{11}+x_{12}+x_{13}+x_{14}+x_{15}+x_{16}+x_{17}} & \leqslant 1 & (4)\\
# {x_{21}+x_{22}+x_{23}+x_{24}+x_{25}+x_{26}+x_{27}} & \leqslant 1 & (5)\\
# {x_{31}+x_{32}+x_{33}+x_{34}+x_{35}+x_{36}+x_{37}} & \leqslant 1 & (6)\\
# {x_{41}+x_{42}+x_{43}+x_{44}+x_{45}+x_{46}+x_{47}} & \leqslant 1 & (7)\\
# {x_{51}+x_{52}+x_{53}+x_{54}+x_{55}+x_{56}+x_{57}} & \leqslant 1 & (8)\\
# {x_{61}+x_{62}+x_{63}+x_{64}+x_{65}+x_{66}+x_{67}} & \leqslant 1 & (9)\\
# {x_{71}+x_{72}+x_{73}+x_{74}+x_{75}+x_{76}+x_{77}} & \leqslant 1 & (10)\\
# \end{align}
# \right.
# $
#
# #### $
# \left\{
# \begin{align}
# {x_{11}+x_{12}+x_{13}+x_{14}+x_{15}+x_{16}+x_{17}} & \geqslant 0 & (11)\\
# {x_{21}+x_{22}+x_{23}+x_{24}+x_{25}+x_{26}+x_{27}} & \geqslant 0 & (12)\\
# {x_{31}+x_{32}+x_{33}+x_{34}+x_{35}+x_{36}+x_{37}} & \geqslant 0 & (13)\\
# {x_{41}+x_{42}+x_{43}+x_{44}+x_{45}+x_{46}+x_{47}} & \geqslant 0 & (14)\\
# {x_{51}+x_{52}+x_{53}+x_{54}+x_{55}+x_{56}+x_{57}} & \geqslant 0 & (15)\\
# {x_{61}+x_{62}+x_{63}+x_{64}+x_{65}+x_{66}+x_{67}} & \geqslant 0 & (16)\\
# {x_{71}+x_{72}+x_{73}+x_{74}+x_{75}+x_{76}+x_{77}} & \geqslant 0 & (17)\\
# \end{align}
# \right.
# $
#
# <span style="font-size: 150%;color:#0000ff"> Krok 4: ograniczenie pośrednie - każdy samochód może być sprzedany tylko raz </span>
#
# #### $
# \left\{
# \begin{align}
# {x_{11}+x_{12}+x_{13}+x_{14}+x_{15}+x_{16}+x_{17}} & = 1 & (1)\\
# {x_{21}+x_{22}+x_{23}+x_{24}+x_{25}+x_{26}+x_{27}} & = 1 & (2)\\
# {x_{31}+x_{32}+x_{33}+x_{34}+x_{35}+x_{36}+x_{37}} & = 1 & (3)\\
# {x_{41}+x_{42}+x_{43}+x_{44}+x_{45}+x_{46}+x_{47}} & = 1 & (4)\\
# {x_{51}+x_{52}+x_{53}+x_{54}+x_{55}+x_{56}+x_{57}} & = 1 & (5)\\
# {x_{61}+x_{62}+x_{63}+x_{64}+x_{65}+x_{66}+x_{67}} & = 1 & (6)\\
# {x_{71}+x_{72}+x_{73}+x_{74}+x_{75}+x_{76}+x_{77}} & = 1 & (7)\\
# \end{align}
# \right.
# $
#
#
#
# <span style="font-size: 150%;color:#0000ff"> Krok 5: jaka jest funkcja celu?</span>

# %% [markdown]
# ![obraz.png](attachment:obraz.png)

# %% [markdown]
# Zmaksymalizować ilość braków.
#
# $
# {
# \\
# F(x_{i,j})\\
# \\=({19.0}\times{x_{11}})+({6.6}\times{x_{12}})+({2.3}\times{x_{13}})+({9.2}\times{x_{14})+({5.0}\times{x_{15}})+({0}\times{x_{16}})+({0}\times{x_{17}})}\\
# \\
# +({17.3}\times{x_{21}})+({7.2}\times{x_{22}})+({2.1}\times{x_{23}})+({8.9}\times{x_{24})+({5.1}\times{x_{25}})+({0}\times{x_{26}})+({0}\times{x_{27}})}\\
# \\
# +({18.3}\times{x_{31}})+({7.8}\times{x_{32}})+({2.8}\times{x_{33}})+({8.5}\times{x_{34})+({5.7}\times{x_{35}})+({0}\times{x_{36}})+({0}\times{x_{37}})}\\
# \\
# +({18.1}\times{x_{41}})+({7.4}\times{x_{42}})+({2.4}\times{x_{43}})+({8.1}\times{x_{44})+({4.8}\times{x_{45}})+({0}\times{x_{46}})+({0}\times{x_{47}})}\\
# \\
# +({18.6}\times{x_{51}})+({8.6}\times{x_{52}})+({2.6}\times{x_{53}})+({8.9}\times{x_{54})+({5.9}\times{x_{55}})+({0}\times{x_{56}})+({0}\times{x_{57}})}\\
# \\
# +({18.0}\times{x_{61}})+({8.2}\times{x_{62}})+({3.1}\times{x_{63}})+({7.9}\times{x_{64})+({5.6}\times{x_{65}})+({0}\times{x_{66}})+({0}\times{x_{67}})}\\
# \\
# +({19.3}\times{x_{71}})+({8.2}\times{x_{72}})+({3.5}\times{x_{73}})+({9.4}\times{x_{74})+({5.7}\times{x_{75}})+({0}\times{x_{76}})+({0}\times{x_{77}})}\\
# \\
# \to  max
# } $

# %%
from pulp import *
from fractions import Fraction

# zdefiniowanie problemu- to jest taka platforma do wrzucania na nia wszystkiego

prob = LpProblem("Przykład_92_STR_144",LpMaximize)

# %% [markdown]
# Wstawianie pierwszych warunków ograniczających: ograniczeniami nieujemności
#
# #### $
# \left\{
# \begin{align}
# {x_{11}} & \geqslant 0 & (4)\\
# {x_{12}} & \geqslant 0 & (5)\\
# {x_{13}} & \geqslant 0 & (5)\\
# {x_{14}} & \geqslant 0 & (5)\\
# {x_{15}} & \geqslant 0 & (5)\\
# {x_{16}} & \geqslant 0 & (5)\\
# {x_{17}} & \geqslant 0 & (5)\\
# {x_{21}} & \geqslant 0 & (5)\\
# {x_{22}} & \geqslant 0 & (5)\\
# {x_{23}} & \geqslant 0 & (5)\\
# {x_{24}} & \geqslant 0 & (5)\\
# {x_{25}} & \geqslant 0 & (5)\\
# {x_{31}} & \geqslant 0 & (5)\\
# {x_{32}} & \geqslant 0 & (5)\\
# {x_{33}} & \geqslant 0 & (5)\\
# {x_{34}} & \geqslant 0 & (5)\\
# {x_{35}} & \geqslant 0 & (5)\\
# \end{align}
# \right.
# $

# %%
# "Continuous"
# "Integer"

x11=LpVariable("x11",lowBound=0,upBound=None, cat="Integer")
x12=LpVariable("x12",lowBound=0,upBound=None, cat="Integer")
x13=LpVariable("x13",lowBound=0,upBound=None, cat="Integer")
x14=LpVariable("x14",lowBound=0,upBound=None, cat="Integer")
x15=LpVariable("x15",lowBound=0,upBound=None, cat="Integer")
x16=LpVariable("x16",lowBound=0,upBound=None, cat="Integer")
x17=LpVariable("x17",lowBound=0,upBound=None, cat="Integer")

x21=LpVariable("x21",lowBound=0,upBound=None, cat="Integer")
x22=LpVariable("x22",lowBound=0,upBound=None, cat="Integer")
x23=LpVariable("x23",lowBound=0,upBound=None, cat="Integer")
x24=LpVariable("x24",lowBound=0,upBound=None, cat="Integer")
x25=LpVariable("x25",lowBound=0,upBound=None, cat="Integer")
x26=LpVariable("x26",lowBound=0,upBound=None, cat="Integer")
x27=LpVariable("x27",lowBound=0,upBound=None, cat="Integer")

x31=LpVariable("x31",lowBound=0,upBound=None, cat="Integer")
x32=LpVariable("x32",lowBound=0,upBound=None, cat="Integer")
x33=LpVariable("x33",lowBound=0,upBound=None, cat="Integer")
x34=LpVariable("x34",lowBound=0,upBound=None, cat="Integer")
x35=LpVariable("x35",lowBound=0,upBound=None, cat="Integer")    
x36=LpVariable("x36",lowBound=0,upBound=None, cat="Integer")    
x37=LpVariable("x37",lowBound=0,upBound=None, cat="Integer")    

x41=LpVariable("x41",lowBound=0,upBound=None, cat="Integer")  
x42=LpVariable("x42",lowBound=0,upBound=None, cat="Integer")  
x43=LpVariable("x43",lowBound=0,upBound=None, cat="Integer")  
x44=LpVariable("x44",lowBound=0,upBound=None, cat="Integer")  
x45=LpVariable("x45",lowBound=0,upBound=None, cat="Integer")
x46=LpVariable("x46",lowBound=0,upBound=None, cat="Integer")
x47=LpVariable("x47",lowBound=0,upBound=None, cat="Integer")

x51=LpVariable("x51",lowBound=0,upBound=None, cat="Integer")  
x52=LpVariable("x52",lowBound=0,upBound=None, cat="Integer")  
x53=LpVariable("x53",lowBound=0,upBound=None, cat="Integer")  
x54=LpVariable("x54",lowBound=0,upBound=None, cat="Integer")  
x55=LpVariable("x55",lowBound=0,upBound=None, cat="Integer")
x56=LpVariable("x56",lowBound=0,upBound=None, cat="Integer")
x57=LpVariable("x57",lowBound=0,upBound=None, cat="Integer")

x61=LpVariable("x61",lowBound=0,upBound=None, cat="Integer")  
x62=LpVariable("x62",lowBound=0,upBound=None, cat="Integer")  
x63=LpVariable("x63",lowBound=0,upBound=None, cat="Integer")  
x64=LpVariable("x64",lowBound=0,upBound=None, cat="Integer")  
x65=LpVariable("x65",lowBound=0,upBound=None, cat="Integer")
x66=LpVariable("x66",lowBound=0,upBound=None, cat="Integer")
x67=LpVariable("x67",lowBound=0,upBound=None, cat="Integer")

x71=LpVariable("x71",lowBound=0,upBound=None, cat="Integer")  
x72=LpVariable("x72",lowBound=0,upBound=None, cat="Integer")  
x73=LpVariable("x73",lowBound=0,upBound=None, cat="Integer")  
x74=LpVariable("x74",lowBound=0,upBound=None, cat="Integer")  
x75=LpVariable("x75",lowBound=0,upBound=None, cat="Integer")
x76=LpVariable("x76",lowBound=0,upBound=None, cat="Integer")
x77=LpVariable("x77",lowBound=0,upBound=None, cat="Integer")

# %% [markdown]
# ### Dodajemy do platformy funkcje celu
#
# Zmaksymalizować ilość braków.
#
# $
# {
# \\
# F(x_{i,j})\\
# \\=({19.0}\times{x_{11}})+({6.6}\times{x_{12}})+({2.3}\times{x_{13}})+({9.2}\times{x_{14})+({5.0}\times{x_{15}})+({0}\times{x_{16}})+({0}\times{x_{17}})}\\
# \\
# +({17.3}\times{x_{21}})+({7.2}\times{x_{22}})+({2.1}\times{x_{23}})+({8.9}\times{x_{24})+({5.1}\times{x_{25}})+({0}\times{x_{26}})+({0}\times{x_{27}})}\\
# \\
# +({18.3}\times{x_{31}})+({7.8}\times{x_{32}})+({2.8}\times{x_{33}})+({8.5}\times{x_{34})+({5.7}\times{x_{35}})+({0}\times{x_{36}})+({0}\times{x_{37}})}\\
# \\
# +({18.1}\times{x_{41}})+({7.4}\times{x_{42}})+({2.4}\times{x_{43}})+({8.1}\times{x_{44})+({4.8}\times{x_{45}})+({0}\times{x_{46}})+({0}\times{x_{47}})}\\
# \\
# +({18.6}\times{x_{51}})+({8.6}\times{x_{52}})+({2.6}\times{x_{53}})+({8.9}\times{x_{54})+({5.9}\times{x_{55}})+({0}\times{x_{56}})+({0}\times{x_{57}})}\\
# \\
# +({18.0}\times{x_{61}})+({8.2}\times{x_{62}})+({3.1}\times{x_{63}})+({7.9}\times{x_{64})+({5.6}\times{x_{65}})+({0}\times{x_{66}})+({0}\times{x_{67}})}\\
# \\
# +({19.3}\times{x_{71}})+({8.2}\times{x_{72}})+({3.5}\times{x_{73}})+({9.4}\times{x_{74})+({5.7}\times{x_{75}})+({0}\times{x_{76}})+({0}\times{x_{77}})}\\
# \\
# \to  max
# } $

# %% [markdown]
# ![obraz.png](attachment:obraz.png)

# %%
# objective function
prob += 19.0*x11+6.6*x12+2.3*x13+9.2*x14+5.0*x15+0*x16+0*x17+17.3*x21+7.2*x22+2.1*x23+8.9*x24+5.1*x25+0*x26+0*x27+18.3*x31+7.8*x32+2.8*x33+8.5*x34+5.7*x35+0*x36+0*x37+18.1*x41+7.4*x42+2.4*x43+8.1*x44+4.8*x45+0*x46+0*x47+18.6*x51+8.6*x52+2.6*x53+8.9*x54+5.9*x55+0*x56+0*x57+18.0*x61+8.2*x62+3.1*x63+7.9*x64+5.6*x65+0*x66+0*x67+19.3*x71+8.2*x72+3.5*x73+9.4*x74+5.7*x75+0*x76+0*x77, "Minimalizacja braków "

# %%
print(prob)
# Out:
# Przykład_92_STR_144:
# MAXIMIZE
# 19.0*x11 + 6.6*x12 + 2.3*x13 + 9.2*x14 + 5.0*x15 + 17.3*x21 + 7.2*x22 + 2.1*x23 + 8.9*x24 + 5.1*x25 + 18.3*x31 + 7.8*x32 + 2.8*x33 + 8.5*x34 + 5.7*x35 + 18.1*x41 + 7.4*x42 + 2.4*x43 + 8.1*x44 + 4.8*x45 + 18.6*x51 + 8.6*x52 + 2.6*x53 + 8.9*x54 + 5.9*x55 + 18.0*x61 + 8.2*x62 + 3.1*x63 + 7.9*x64 + 5.6*x65 + 19.3*x71 + 8.2*x72 + 3.5*x73 + 9.4*x74 + 5.7*x75 + 0.0
# VARIABLES
# 0 <= x11 Integer
# 0 <= x12 Integer
# 0 <= x13 Integer
# 0 <= x14 Integer
# 0 <= x15 Integer
# 0 <= x21 Integer
# 0 <= x22 Integer
# 0 <= x23 Integer
# 0 <= x24 Integer
# 0 <= x25 Integer
# 0 <= x31 Integer
# 0 <= x32 Integer
# 0 <= x33 Integer
# 0 <= x34 Integer
# 0 <= x35 Integer
# 0 <= x41 Integer
# 0 <= x42 Integer
# 0 <= x43 Integer
# 0 <= x44 Integer
# 0 <= x45 Integer
# 0 <= x51 Integer
# 0 <= x52 Integer
# 0 <= x53 Integer
# 0 <= x54 Integer
# 0 <= x55 Integer
# 0 <= x61 Integer
# 0 <= x62 Integer
# 0 <= x63 Integer
# 0 <= x64 Integer
# 0 <= x65 Integer
# 0 <= x71 Integer
# ...

# %% [markdown]
# TWORZONY JEST JEDEN WIĘCEJ SAMOCHÓD FANTOMOWY
#
# #### $
# \left\{
# \begin{align}
# {x_{11}+x_{12}+x_{13}+x_{14}+x_{15}+x_{16}+x_{17}} & \leqslant 1 & (1)\\
# {x_{21}+x_{22}+x_{23}+x_{24}+x_{25}+x_{26}+x_{27}} & \leqslant 1 & (2)\\
# {x_{31}+x_{32}+x_{33}+x_{34}+x_{35}+x_{36}+x_{37}} & \leqslant 1 & (3)\\
# {x_{41}+x_{42}+x_{43}+x_{44}+x_{45}+x_{46}+x_{47}} & \leqslant 1 & (4)\\
# {x_{51}+x_{52}+x_{53}+x_{54}+x_{55}+x_{56}+x_{57}} & \leqslant 1 & (5)\\
# {x_{61}+x_{62}+x_{63}+x_{64}+x_{65}+x_{66}+x_{67}} & \leqslant 1 & (6)\\
# {x_{71}+x_{72}+x_{73}+x_{74}+x_{75}+x_{76}+x_{77}} & \leqslant 1 & (7)\\
# \end{align}
# \right.
# $
#
# #### $
# \left\{
# \begin{align}
# {x_{11}+x_{12}+x_{13}+x_{14}+x_{15}+x_{16}+x_{17}} & \geqslant 0 & (8)\\
# {x_{21}+x_{22}+x_{23}+x_{24}+x_{25}+x_{26}+x_{27}} & \geqslant 0 & (9)\\
# {x_{31}+x_{32}+x_{33}+x_{34}+x_{35}+x_{36}+x_{37}} & \geqslant 0 & (10)\\
# {x_{41}+x_{42}+x_{43}+x_{44}+x_{45}+x_{46}+x_{47}} & \geqslant 0 & (11)\\
# {x_{51}+x_{52}+x_{53}+x_{54}+x_{55}+x_{56}+x_{57}} & \geqslant 0 & (12)\\
# {x_{61}+x_{62}+x_{63}+x_{64}+x_{65}+x_{66}+x_{67}} & \geqslant 0 & (13)\\
# {x_{71}+x_{72}+x_{73}+x_{74}+x_{75}+x_{76}+x_{77}} & \geqslant 0 & (14)\\
# \end{align}
# \right.
# $
#
# <span style="font-size: 150%;color:#0000ff"> Krok 4: ograniczenie pośrednie - każdy Nabywca może kupić tylko jedną maszynę </span>
#
# #### $
# \left\{
# \begin{align}
# {x_{11}+x_{12}+x_{13}+x_{14}+x_{15}+x_{16}+x_{17}} & = 1 & (4)\\
# {x_{21}+x_{22}+x_{23}+x_{24}+x_{25}+x_{26}+x_{27}} & = 1 & (5)\\
# {x_{31}+x_{32}+x_{33}+x_{34}+x_{35}+x_{36}+x_{37}} & = 1 & (6)\\
# {x_{41}+x_{42}+x_{43}+x_{44}+x_{45}+x_{46}+x_{47}} & = 1 & (7)\\
# {x_{51}+x_{52}+x_{53}+x_{54}+x_{55}+x_{56}+x_{57}} & = 1 & (8)\\
# {x_{61}+x_{62}+x_{63}+x_{64}+x_{65}+x_{66}+x_{67}} & = 1 & (9)\\
# {x_{71}+x_{72}+x_{73}+x_{74}+x_{75}+x_{76}+x_{77}} & = 1 & (10)\\
# \end{align}
# \right.
# $
# <span style="font-size: 150%;color:#0000ff"> Krok 4: ograniczenie pośrednie - każda maszyna może być sprzedany tylko raz </span
#
# #### $
# \left\{
# \begin{align}
# {x_{11}+x_{21}+x_{31}+x_{41}+x_{51}+x_{61}+x_{71}} & = 1 & (11)\\
# {x_{12}+x_{22}+x_{32}+x_{42}+x_{52}+x_{62}+x_{72}} & = 1 & (12)\\
# {x_{13}+x_{23}+x_{33}+x_{43}+x_{53}+x_{63}+x_{73}} & = 1 & (13)\\
# {x_{14}+x_{24}+x_{34}+x_{44}+x_{54}+x_{64}+x_{74}} & = 1 & (14)\\
# {x_{15}+x_{25}+x_{35}+x_{45}+x_{55}+x_{65}+x_{75}} & = 1 & (15)\\
# {x_{16}+x_{26}+x_{36}+x_{46}+x_{56}+x_{66}+x_{76}} & = 1 & (16)\\
# {x_{17}+x_{27}+x_{37}+x_{47}+x_{57}+x_{67}+x_{77}} & = 1 & (17)\\
# \end{align}
# \right.
# $

# %%
# OGRANICZENIA DLA NABYWCÓW (+ KOLUMNY MASZYN FANTOMOWYCH)
prob += x11 + x12 + x13 + x14 + x15 + x16 + x17 == 1  # NABYWCA
prob += x21 + x22 + x23 + x24 + x25 + x26 + x27 == 1  # PRACOWNIK B
prob += x31 + x32 + x33 + x34 + x35 + x36 + x37 == 1  # PRACOWNIK C
prob += x41 + x42 + x43 + x44 + x45 + x46 + x47 == 1  # PRACOWNIK D
prob += x51 + x52 + x53 + x54 + x55 + x56 + x57 == 1  # PRACOWNIK D
prob += x61 + x62 + x63 + x64 + x65 + x66 + x67 == 1  # PRACOWNIK D
prob += x71 + x72 + x73 + x74 + x75 + x76 + x77 == 1  # PRACOWNIK D

# %%
# OGRANICZENIA DLA SAMOCHODÓW (CZWARTA KOLUMNA TO SAMOCHÓD FANTOMOWY)
prob += x11 + x21 + x31 + x41 + x51 + x61 + x71 == 1
prob += x12 + x22 + x32 + x42 + x52 + x62 + x72 == 1
prob += x13 + x23 + x33 + x43 + x53 + x63 + x73 == 1
prob += x14 + x24 + x34 + x44 + x54 + x64 + x74 == 1
prob += x15 + x25 + x35 + x45 + x55 + x65 + x75 == 1
prob += x16 + x26 + x36 + x46 + x56 + x66 + x76 == 1
prob += x17 + x27 + x37 + x47 + x57 + x67 + x77 == 1

# %%
print(prob)
# Out:
# Przykład_92_STR_144:
# MAXIMIZE
# 19.0*x11 + 6.6*x12 + 2.3*x13 + 9.2*x14 + 5.0*x15 + 17.3*x21 + 7.2*x22 + 2.1*x23 + 8.9*x24 + 5.1*x25 + 18.3*x31 + 7.8*x32 + 2.8*x33 + 8.5*x34 + 5.7*x35 + 18.1*x41 + 7.4*x42 + 2.4*x43 + 8.1*x44 + 4.8*x45 + 18.6*x51 + 8.6*x52 + 2.6*x53 + 8.9*x54 + 5.9*x55 + 18.0*x61 + 8.2*x62 + 3.1*x63 + 7.9*x64 + 5.6*x65 + 19.3*x71 + 8.2*x72 + 3.5*x73 + 9.4*x74 + 5.7*x75 + 0.0
# SUBJECT TO
# _C1: x11 + x12 + x13 + x14 + x15 + x16 + x17 = 1
#
# _C2: x21 + x22 + x23 + x24 + x25 + x26 + x27 = 1
#
# _C3: x31 + x32 + x33 + x34 + x35 + x36 + x37 = 1
#
# _C4: x41 + x42 + x43 + x44 + x45 + x46 + x47 = 1
#
# _C5: x11 + x12 + x13 + x14 + x15 + x16 + x17 = 1
#
# _C6: x21 + x22 + x23 + x24 + x25 + x26 + x27 = 1
#
# _C7: x31 + x32 + x33 + x34 + x35 + x36 + x37 = 1
#
# _C8: x41 + x42 + x43 + x44 + x45 + x46 + x47 = 1
#
# _C9: x51 + x52 + x53 + x54 + x55 + x56 + x57 = 1
#
# _C10: x61 + x62 + x63 + x64 + x65 + x66 + x67 = 1
#
# _C11: x71 + x72 + x73 + x74 + x75 + x76 + x77 = 1
#
# ...

# %%
print(prob)
# Out:
# Przykład_92_STR_144:
# MAXIMIZE
# 19.0*x11 + 6.6*x12 + 2.3*x13 + 9.2*x14 + 5.0*x15 + 17.3*x21 + 7.2*x22 + 2.1*x23 + 8.9*x24 + 5.1*x25 + 18.3*x31 + 7.8*x32 + 2.8*x33 + 8.5*x34 + 5.7*x35 + 18.1*x41 + 7.4*x42 + 2.4*x43 + 8.1*x44 + 4.8*x45 + 18.6*x51 + 8.6*x52 + 2.6*x53 + 8.9*x54 + 5.9*x55 + 18.0*x61 + 8.2*x62 + 3.1*x63 + 7.9*x64 + 5.6*x65 + 19.3*x71 + 8.2*x72 + 3.5*x73 + 9.4*x74 + 5.7*x75 + 0.0
# SUBJECT TO
# _C1: x11 + x12 + x13 + x14 + x15 + x16 + x17 = 1
#
# _C2: x21 + x22 + x23 + x24 + x25 + x26 + x27 = 1
#
# _C3: x31 + x32 + x33 + x34 + x35 + x36 + x37 = 1
#
# _C4: x41 + x42 + x43 + x44 + x45 + x46 + x47 = 1
#
# _C5: x11 + x12 + x13 + x14 + x15 + x16 + x17 = 1
#
# _C6: x21 + x22 + x23 + x24 + x25 + x26 + x27 = 1
#
# _C7: x31 + x32 + x33 + x34 + x35 + x36 + x37 = 1
#
# _C8: x41 + x42 + x43 + x44 + x45 + x46 + x47 = 1
#
# _C9: x51 + x52 + x53 + x54 + x55 + x56 + x57 = 1
#
# _C10: x61 + x62 + x63 + x64 + x65 + x66 + x67 = 1
#
# _C11: x71 + x72 + x73 + x74 + x75 + x76 + x77 = 1
#
# ...

# %% [markdown]
# ### Rozwiązanie problemu

# %%
print("prob.solve",prob.solve())
# status of the solution
print(f"Status: {LpStatus[prob.status]}")
# Out:
# prob.solve 1
# Status: Optimal

# %%
for v in prob.variables():
    print(f"{v.name} = {str(Fraction(v.varValue).limit_denominator())}")
# Out:
# x11 = 0
# x12 = 0
# x13 = 0
# x14 = 1
# x15 = 0
# x16 = 0
# x17 = 0
# x21 = 0
# x22 = 0
# x23 = 0
# x24 = 0
# x25 = 0
# x26 = 0
# x27 = 1
# x31 = 0
# x32 = 0
# x33 = 0
# x34 = 0
# x35 = 1
# x36 = 0
# x37 = 0
# x41 = 0
# x42 = 0
# x43 = 0
# x44 = 0
# x45 = 0
# x46 = 1
# x47 = 0
# x51 = 0
# x52 = 1
# x53 = 0
# x54 = 0
# x55 = 0
# x56 = 0
# x57 = 0
# x61 = 0
# x62 = 0
# x63 = 1
# x64 = 0
# x65 = 0
# x66 = 0
# x67 = 0
# x71 = 1
# x72 = 0
# x73 = 0
# x74 = 0
# x75 = 0
# x76 = 0
# x77 = 0

# %%
# maximum value of the objective function
print(f"max (x11+x12+x13+x21+x22+x23+x31+x32+x33+x41+x42+x43) = {str(Fraction(value(prob.objective)).limit_denominator())}")
# Out:
# max (x11+x12+x13+x21+x22+x23+x31+x32+x33+x41+x42+x43) = 459/10

# %% [markdown]
# - Pracownik A kupił samochód za 0 tys. zł (brak zakupu)
# - Pracownik B kupił samochód za 21 tys. zł (Ford)
# - Pracownik C kupił samochód za 40 tys. zł (Mercedes)
# - Pracownik D kupił samochód za 16 tys. zł (Polonez)

# %%
21+40+16
# Out:
# 77

# %%
p11 ="--"
p12 ="--"
p13 ="--"
p14 ="9.2 tys. zł"
p15 ="--"

p21 ="--"
p22 ="--"
p23 ="--"
p24 ="--"
p25 ="--"

p31 ="--"
p32 ="--"
p33 ="--"
p34 ="--"
p35 ="5.7 tys. zł" 

p41 ="--"
p42 ="--"
p43 ="--"
p44 ="--"
p45 ="--"

p51 ="--"
p52 ="8.6 tys. zł"
p53 ="--"
p54 ="--"
p55 ="--" 

p61 ="--"
p62 ="--"
p63 ="3.1 tys. zł"
p64 ="--"
p65 ="--"

p71 ="19.3 tys. zł"
p72 ="--"
p73 ="--"
p74 ="--"
p75 ="--"

# %%
from prettytable import PrettyTable
t = PrettyTable(["Oferty :", "Piec","Wymiennik","Miesiarka plan.","Mikser spir.","Krajalnica"])

#t.align["Sulejówek PKP"] = "i"
#t.padding_width = 1
t.add_row(['Piekarnia Szamoty',p11,  p12,  p13,  p14, p15])
t.add_row(['Piekarnia Morsk',p21,  p22,  p23,  p24, p25])
t.add_row(['Pracownik 1',p31,  p32,  p33,  p34, p35])
t.add_row(['Pracownik 2',p41,  p42,  p43,  p44, p45])
t.add_row(['Piekarnia Krystyna',p51,  p52,  p53,  p54, p55])
t.add_row(['Szkoła piekarnicza',p61,  p62,  p63,  p64, p65])
t.add_row(['Piekarnia Falenty',p71,  p72,  p73,  p74, p75])
print(t)
# Out:
# +--------------------+--------------+-------------+-----------------+--------------+-------------+
# |      Oferty :      |     Piec     |  Wymiennik  | Miesiarka plan. | Mikser spir. |  Krajalnica |
# +--------------------+--------------+-------------+-----------------+--------------+-------------+
# | Piekarnia Szamoty  |      --      |      --     |        --       | 9.2 tys. zł  |      --     |
# |  Piekarnia Morsk   |      --      |      --     |        --       |      --      |      --     |
# |    Pracownik 1     |      --      |      --     |        --       |      --      | 5.7 tys. zł |
# |    Pracownik 2     |      --      |      --     |        --       |      --      |      --     |
# | Piekarnia Krystyna |      --      | 8.6 tys. zł |        --       |      --      |      --     |
# | Szkoła piekarnicza |      --      |      --     |   3.1 tys. zł   |      --      |      --     |
# ...

# %% [markdown]
# ![obraz.png](attachment:obraz.png)

# %% [markdown]
# ![obraz.png](attachment:obraz.png)

# %%
Krystyna 5.9
Falenty 9.4
Szkoła 3.1
prac_1  7.8
Szamoty 19
# Out:
# 45.900000000000006

# %%
5.9+9.4+3.1+7.8+19
# Out:
# 45.2

# %%
Falenty 19.3 
Krystyna 8.6
Prac_1  2.8
Szamoty 9.2
Szkoła 5.6
# Out:
# 459.0

# %%
19.3+8.6+2.8+9.2+5.6
# Out:
# 45.5

# %% [markdown]
# <font size="6">
# <font color="black">
# $
# {
# 1 \geqslant \displaystyle {x_{(i,j)\,}}  \geqslant 0  {...} \forall  {i \in I},{j \in J} \\
# \displaystyle {x_{(i,j)\,}}  \in \mathbb{Z}^+  {...} \forall  {i \in I},{j \in J} \\
# }
# $
#
# <font size="2">
# <font color="grey">
#
# ${
# \text{i,j - niewiadome reprezentowanych jako x  większe równe zero} \\
# \text{dla każdego elementu zbioru wierszy I i kolumn J} \\
# }
# $
#
#
# <font size="6">
# <font color="black">
# $
# {
#  \displaystyle {x_{(i,j)\,}}  \in \mathbb{Z}^+  {...} \forall  {i \in I},{j \in J} \\
# }
# $
#
# <font size="2">
# <font color="grey">
#
# $ {
# \text{i,j - niewiadome reprezentowane jako x należą do zbioru liczb całkowitych dodatnich} \\
# \text{dla każdego elementu zbioru wierszy I i kolumn J} \\
# }
# $
